# %% [markdown]
# <a href="https://colab.research.google.com/github/mihhwiNick/DA_project/blob/huy/UK_Road_Traffic_Accident_DA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PHÂN TÍCH VÀ DỰ BÁO XU HƯỚNG TAI NẠN GIAO THÔNG TỪ DỮ LIỆU LỚN TẠI ANH QUỐC**

# %% [markdown]
# ## **1. Định nghĩa vấn đề (Define Problem)**

# %% [markdown]
# ### **1.1. Mô tả (Description)**
# + Phạm vi: Dữ liệu về An toàn Giao thông Đường bộ Vương quốc Anh (UK Road Safety: Traffic Accidents and Vehicles) giai đoạn 2005-2017. Dữ liệu được cung cấp chính thức từ UK Department for Transport (Bộ Giao thông Vận tải Anh).
# + Kích thước: Gồm 2 tệp dữ liệu chính với hơn 2 triệu bản ghi về tai nạn và thông tin phương tiện liên quan.
# + Đặc điểm: Gồm 2 tệp (Accident_information và Vehicle_information) liên kết với nhau qua khóa Accident_Index. Dữ liệu có tính uy tín cao, được sử dụng rộng rãi trên Kaggle (140K lượt xem, 17.3K lượt tải).

# %% [markdown]
# ### **1.2. Dữ liệu vào (Input Data)**
# + **A. Tệp Accident_Information (Thông tin tai nạn):**
#   + **Nhóm 1: Thông tin thời gian:**
#     + Date: Ngày xảy ra tai nạn.
#     + Time: Thời gian xảy ra tai nạn.
#     + Day_of_Week: Thứ trong tuần.
#     + Year: Năm xảy ra tai nạn.
#   + **Nhóm 2: Thông tin địa lí và vị trí:**
#     + Latitude: Vĩ độ.
#     + Longitude: Kinh độ.
#     + Location_Easting_OSGR: Tọa độ đông OSGR.
#     + Location_Northing_OSGR: Tọa độ bắc OSGR.
#     + Urban_or_Rural_Area: Khu vực thành thị hay nông thôn.
#     + Local_Authority_(District): Khu vực hành chính địa phương.
#     + Local_Authority_(Highway): Cơ quan quản lý đường bộ địa phương.
#     + LSOA_of_Accident_Location: Khu vực thống kê của vị trí tai nạn.
#   + **Nhóm 3: Đặc điểm đường và giao lộ:**
#     + 1st_Road_Class, 1st_Road_Number: Hạng và số hiệu đường chính
#     + 2nd_Road_Class, 2nd_Road_Number: Hạng và số hiệu đường thứ hai
#     + Road_Type: Loại đường
#     + Speed_Limit: Tốc độ giới hạn
#     + Junction_Control, Junction_Detail: Cách kiểm soát và chi tiết giao lộ
#   + **Nhóm 4: Điều kiện môi trường và hiện trường:**
#     + Light_Conditions: Điều kiện ánh sáng
#     + Weather_Conditions: Điều kiện thời tiết
#     + Road_Surface_Conditions: Tình trạng bề mặt đường
#     + Special_Conditions_at_Site: Điều kiện đặc biệt tại hiện trường
#     + Carriageway_Hazards: Nguy cơ/chướng ngại vật trên đường xe chạy
#   + **Nhóm 5: Hậu quả và đáp ứng:**
#     + Number_of_Vehicles: Số phương tiện liên quan
#     + Number_of_Casualties: Số lượng nạn nhân
#     + Did_Police_Officer_Attend_Scene_of_Accident: Cảnh sát có mặt tại hiện trường không?
#     + Police_Force: Vùng Địa lý mà Lực lượng Cảnh sát đó phụ trách quản lý
#     + Pedestrian_Crossing-Human_Control: Người điều khiển vạch sang đường
#     + Pedestrian_Crossing-Physical_Facilities: Cơ sở vật chất cho người đi bộ
#     + InScotland: Tai nạn có xảy ra ở Scotland không
#
# + **B. Tệp Vehicle_Information (Thông tin phương tiện)**
#
#   + **Nhóm 1: Thông tin phương tiện:**
#     + Vehicle_Type: Loại xe
#     + make, model: Hãng xe và mẫu xe
#     + Age_of_Vehicle: Tuổi của xe
#     + Engine_Capacity_.CC.: Dung tích động cơ
#     + Propulsion_Code: Loại động cơ
#     + Was_Vehicle_Left_Hand_Drive: Có phải xe tay lái nghịch không
#     + Year: Năm sản xuất phương tiện
#   + **Nhóm 2: Thông tin người lái và hành trình:**
#     + Sex_of_Driver: Giới tính của tài xế
#     + Age_Band_of_Driver: Nhóm tuổi của tài xế
#     + Journey_Purpose_of_Driver: Mục đích chuyến đi
#     + Driver_Home_Area_Type: Loại khu vực cư trú của tài xế
#     + Driver_IMD_Decile: Mức độ thiếu thốn của tài xế
#   + **Nhóm 3: Động lực học va chạm:**
#     + Vehicle_Manoeuvre: Thao tác của xe trước khi va chạm
#     + X1st_Point_of_Impact: Điểm va chạm đầu tiên
#     + Vehicle_Leaving_Carriageway: Xe có rời khỏi phần đường xe chạy không
#     + Skidding_and_Overturning: Có trượt bánh và lật xe không
#     + Hit_Object_in_Carriageway: Vật thể bị va chạm trên làn đường
#     + Hit_Object_off_Carriageway: Vật thể bị va chạm ngoài làn đường
#     + Junction_Location: Vị trí tại giao lộ
#     + Towing_and_Articulation: Tình trạng kéo theo hoặc đầu kéo
#     + Vehicle_Location.Restricted_Lane: Vị trí xe trên làn đường bị hạn chế

# %% [markdown]
# ### **1.3. Dữ liệu ra (Output Data)**
#   + Biến mục tiêu (Output variable): **Accident_Severity**: Mức độ nghiêm trọng của tai nạn
#   + Kết quả phân tích:
#     + Các phát hiện/Insight về thực trạng, xu hướng và các yếu tố then chốt ảnh hưởng đến tai nạn giao thông.
#     + Mô hình dự báo mức độ nghiêm trọng của tai nạn.
#     + Các giải pháp và khuyến nghị chính sách.

# %% [markdown]
# ### **1.4. Mục tiêu nghiên cứu (Research Objective)**
# + Phân tích thực trạng và xu hướng tai nạn giao thông theo thời gian, không gian và các điều kiện vận hành.
# + Xác định các yếu tố then chốt ảnh hưởng đến tần suất và mức độ nghiêm trọng của tai nạn.
# + Xây dựng và đánh giá mô hình dự báo mức độ nghiêm trọng tai nạn dựa trên các thuật toán học máy.
# + Đề xuất các giải pháp và khuyến nghị chính sách dựa trên kết quả phân tích.

# %% [markdown]
# ##**2. Chuẩn bị vấn đề (Prepare Problem)**

# %% [markdown]
# ###**2.1. Khai báo thư viện (Load Libraries)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from matplotlib.ticker import MaxNLocator, FuncFormatter

# %% [markdown]
# ###**2.2. Nạp dữ liệu (Load Dataset)**

# %%
import pandas as pd
import gdown

VEHICLE_FILE_ID = '1sVAqb9IsYgfjHRNVNNOflOg0twFqz-l5'
ACCIDENT_FILE_ID = '1o4lM2JuIKEh1ySWHWIaejQ7oFz_hTlmt'

def load_data():
    print("Đang tải dữ liệu từ Google Drive...")

    # Tải file từ Google Drive
    gdown.download(f'https://drive.google.com/uc?id={ACCIDENT_FILE_ID}', 'accident.csv', quiet=True)
    gdown.download(f'https://drive.google.com/uc?id={VEHICLE_FILE_ID}', 'vehicle.csv', quiet=True)

    print("Đang đọc file...")
    # Đọc file
    accident_df = pd.read_csv('accident.csv', encoding='latin1',low_memory=False)
    vehicle_df = pd.read_csv('vehicle.csv', encoding='latin1',low_memory=False)

    return accident_df, vehicle_df

# Load dữ liệu
Accident, Vehicle = load_data()
print(f"ĐÃ LOAD DỮ LIỆU THÀNH CÔNG!")
# Out:
# Đang tải dữ liệu từ Google Drive...
# Đang đọc file...
# ĐÃ LOAD DỮ LIỆU THÀNH CÔNG!

# %% [markdown]
# ##**3. Thống kê mô tả (Descriptive Statistics)**

# %% [markdown]
# ### **3.1. File Accident_Information**

# %% [markdown]
# #### **(1) Hiển thị một số thông tin về dữ liệu**
# + Số dòng, số cột của dữ liệu
# + 2 dòng đầu và 2 dòng cuối của bảng dữ liệu
# + Thông tin chung về dữ liệu

# %%
# shape
print(f'+ Shape: {Accident.shape}')
# head, tail
print(f'+ Contents: ')
display(Accident.head(2))
display(Accident.tail(2))
# info
Accident.info()
# Out:
# + Shape: (2047256, 34)
# + Contents:
#   Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 0  200501BS00001              A           3218.0            NaN
# 1  200501BS00002              B            450.0              C
#
#    2nd_Road_Number Accident_Severity Carriageway_Hazards        Date  \
# 0              0.0           Serious                 NaN  2005-01-04
# 1              0.0            Slight                 NaN  2005-01-05
#
#   Day_of_Week  Did_Police_Officer_Attend_Scene_of_Accident  ...  \
# 0     Tuesday                                          1.0  ...
# 1   Wednesday                                          1.0  ...
#
#           Police_Force Road_Surface_Conditions           Road_Type  \
# 0  Metropolitan Police             Wet or damp  Single carriageway
# 1  Metropolitan Police                     Dry    Dual carriageway
#
#   Special_Conditions_at_Site Speed_limit   Time  Urban_or_Rural_Area  \
# 0                        NaN        30.0  17:42                Urban
# 1                        NaN        30.0  17:36                Urban
#
#       Weather_Conditions  Year InScotland
# 0  Raining no high winds  2005         No
# 1     Fine no high winds  2005         No
#
# [2 rows x 34 columns]
#         Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 2047254  2017984122317              A            708.0            NaN
# 2047255  2017984122617              B            721.0              B
#
#          2nd_Road_Number Accident_Severity Carriageway_Hazards        Date  \
# 2047254              0.0            Slight                 NaN  2017-07-18
# 2047255            724.0           Serious                 NaN  2017-12-20
#
#         Day_of_Week  Did_Police_Officer_Attend_Scene_of_Accident  ...  \
# 2047254     Tuesday                                          1.0  ...
# 2047255   Wednesday                                          1.0  ...
#
#                   Police_Force Road_Surface_Conditions           Road_Type  \
# 2047254  Dumfries and Galloway                     Dry  Single carriageway
# 2047255  Dumfries and Galloway             Wet or damp  Single carriageway
#
#         Special_Conditions_at_Site Speed_limit   Time  Urban_or_Rural_Area  \
# 2047254                        NaN        60.0  18:00                Rural
# 2047255                        NaN        40.0  13:00                Rural
#
#          Weather_Conditions  Year InScotland
# 2047254  Fine no high winds  2017        Yes
# 2047255         Fog or mist  2017        Yes
#
# [2 rows x 34 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2047256 entries, 0 to 2047255
# Data columns (total 34 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   Accident_Index                               object
#  1   1st_Road_Class                               object
#  2   1st_Road_Number                              float64
#  3   2nd_Road_Class                               object
#  4   2nd_Road_Number                              float64
#  5   Accident_Severity                            object
#  6   Carriageway_Hazards                          object
#  7   Date                                         object
#  8   Day_of_Week                                  object
#  9   Did_Police_Officer_Attend_Scene_of_Accident  float64
#  10  Junction_Control                             object
#  11  Junction_Detail                              object
#  12  Latitude                                     float64
#  13  Light_Conditions                             object
#  14  Local_Authority_(District)                   object
#  15  Local_Authority_(Highway)                    object
#  16  Location_Easting_OSGR                        float64
#  17  Location_Northing_OSGR                       float64
#  18  Longitude                                    float64
#  19  LSOA_of_Accident_Location                    object
#  20  Number_of_Casualties                         int64
#  21  Number_of_Vehicles                           int64
#  22  Pedestrian_Crossing-Human_Control            float64
#  23  Pedestrian_Crossing-Physical_Facilities      float64
#  24  Police_Force                                 object
#  25  Road_Surface_Conditions                      object
#  26  Road_Type                                    object
#  27  Special_Conditions_at_Site                   object
#  28  Speed_limit                                  float64
#  29  Time                                         object
#  30  Urban_or_Rural_Area                          object
#  31  Weather_Conditions                           object
#  32  Year                                         int64
#  33  InScotland                                   object
# dtypes: float64(10), int64(3), object(21)
# memory usage: 531.1+ MB

# %% [markdown]
# **Thông tin cơ bản của dữ liệu:**
# + Dữ liệu có 34 tính chất (cột) để phân tích.
# + Các giá trị thuộc đa số thuộc kiểu object (chuỗi/text) với 21 cột, 10 kiểu float64 (các cột số thực như tọa độ, số đường), và 3 kiểu int64 (các cột Number_of_Casualties, Number_of_Vehicles, Year).
# + Tổng số dòng dữ liệu là 2,047,256 bản ghi (vụ tai nạn).
# + Bộ dữ liệu này không có cột phân lớp. Đây là dữ liệu an toàn giao thông/ghi chép tai nạn, trong đó cột Accident_Severity (mức độ nghiêm trọng tai nạn) là biến chính để phân tích.

# %% [markdown]
# #### **(2) Kiểm tra tính toàn vẹn của dữ liệu**
# + Dữ liệu có bị trùng lặp không? Hiển thị dòng bị vi phạm.
# + Dữ liệu có tồn tại giá trị Null/NaN không? Hiển thị dòng bị vi phạm.

# %%
# Kiểm tra dữ liệu trùng lặp
n_duplicated = Accident.duplicated().sum()
print(f'- Số dòng trùng lặp: {n_duplicated}')

# Thống kê chi tiết các cột có giá trị missing
print("- Thống kê chi tiết giá trị missing theo cột:")
missing_stats = Accident.isnull().sum()
missing_percent = (Accident.isnull().sum() / len(Accident)) * 100
missing_df = pd.DataFrame({
    'Số lượng missing': missing_stats,
    'Tỷ lệ %': missing_percent
}).sort_values('Số lượng missing', ascending=False)
missing_df = missing_df[missing_df['Số lượng missing'] > 0]
display(missing_df)
# Out:
# - Số dòng trùng lặp: 0
# - Thống kê chi tiết giá trị missing theo cột:
#                                              Số lượng missing    Tỷ lệ %
# Carriageway_Hazards                                   2007807  98.073079
# Special_Conditions_at_Site                            1995137  97.454202
# 2nd_Road_Class                                         844272  41.239200
# LSOA_of_Accident_Location                              144953   7.080355
# 2nd_Road_Number                                         17593   0.859345
# Pedestrian_Crossing-Physical_Facilities                  3560   0.173891
# Pedestrian_Crossing-Human_Control                        2920   0.142630
# Did_Police_Officer_Attend_Scene_of_Accident               278   0.013579
# Longitude                                                 175   0.008548
# Latitude                                                  174   0.008499
# Location_Easting_OSGR                                     164   0.008011
# Location_Northing_OSGR                                    164   0.008011
# Time                                                      156   0.007620
# InScotland                                                 53   0.002589
# Speed_limit                                                37   0.001807
# 1st_Road_Number                                             2   0.000098

# %% [markdown]
# **Nhận xét:**
# + Dữ liệu không có dòng nào bị trùng lặp (0 dòng trùng)
# + Dữ liệu có tồn tại giá trị missing, cụ thể: cột **Carriageway_Hazards** và **Special_Conditions_at_Site** có tỷ lệ missing rất cao (>97%), cần xem xét loại bỏ. Bên cạnh đó cột **2nd_Road_Class** cũng có tỷ lệ missing khá cao (41.24%) và hầu hết các cột khác có tỷ lệ missing thấp (<8%) hoặc rất thấp (<1%)

# %% [markdown]
# #### **(3) Các tính chất thống kê trên dữ liệu số**
# + Count, Mean, Standard Deviation
# + Minimum Value, 25th Percentile, 50th Percentile (Median), 75th Percentile, Maximum Value

# %%
description_accident = Accident.select_dtypes(include=['number']).describe().T
display(description_accident)
# Out:
#                                                  count           mean  \
# 1st_Road_Number                              2047254.0     992.105099
# 2nd_Road_Number                              2029663.0     372.815342
# Did_Police_Officer_Attend_Scene_of_Accident  2046978.0       1.202319
# Latitude                                     2047082.0      52.559780
# Location_Easting_OSGR                        2047092.0  441446.210036
# Location_Northing_OSGR                       2047092.0  296885.465668
# Longitude                                    2047081.0      -1.410155
# Number_of_Casualties                         2047256.0       1.345843
# Number_of_Vehicles                           2047256.0       1.833525
# Pedestrian_Crossing-Human_Control            2044336.0       0.010417
# Pedestrian_Crossing-Physical_Facilities      2043696.0       0.751802
# Speed_limit                                  2047219.0      38.843597
# Year                                         2047256.0    2010.523806
#
#                                                        std           min  \
# 1st_Road_Number                                1809.407936      0.000000
# 2nd_Road_Number                                1287.796383      0.000000
# Did_Police_Officer_Attend_Scene_of_Accident       0.408194      1.000000
# Latitude                                          1.445506     49.912941
# Location_Easting_OSGR                         95496.198208  64950.000000
# Location_Northing_OSGR                       160527.257527  10290.000000
# Longitude                                         1.403532     -7.516225
# Number_of_Casualties                              0.817963      1.000000
# Number_of_Vehicles                                0.715054      1.000000
# Pedestrian_Crossing-Human_Control                 0.135113      0.000000
# Pedestrian_Crossing-Physical_Facilities           1.835289      0.000000
# Speed_limit                                      14.147910      0.000000
# Year                                              3.765624   2005.000000
#
#                                                        25%            50%  \
# 1st_Road_Number                                   0.000000     118.000000
# 2nd_Road_Number                                   0.000000       0.000000
# Did_Police_Officer_Attend_Scene_of_Accident       1.000000       1.000000
# Latitude                                         51.485404      52.237583
# Location_Easting_OSGR                        378063.500000  443050.000000
# Location_Northing_OSGR                       177756.750000  261183.500000
# Longitude                                        -2.329610      -1.362233
# Number_of_Casualties                              1.000000       1.000000
# Number_of_Vehicles                                1.000000       2.000000
# Pedestrian_Crossing-Human_Control                 0.000000       0.000000
# Pedestrian_Crossing-Physical_Facilities           0.000000       0.000000
# Speed_limit                                      30.000000      30.000000
# Year                                           2007.000000    2010.000000
#
#                                                        75%           max
# 1st_Road_Number                                 702.000000  9.999000e+03
# 2nd_Road_Number                                   0.000000  9.999000e+03
# Did_Police_Officer_Attend_Scene_of_Accident       1.000000  3.000000e+00
# Latitude                                         53.455902  6.075754e+01
# Location_Easting_OSGR                        524298.250000  6.555400e+05
# Location_Northing_OSGR                       395610.000000  1.208800e+06
# Longitude                                        -0.205260  1.762010e+00
# Number_of_Casualties                              1.000000  9.300000e+01
# Number_of_Vehicles                                2.000000  6.700000e+01
# Pedestrian_Crossing-Human_Control                 0.000000  2.000000e+00
# Pedestrian_Crossing-Physical_Facilities           0.000000  8.000000e+00
# Speed_limit                                      50.000000  7.000000e+01
# Year                                           2014.000000  2.017000e+03

# %% [markdown]
# **Nhận xét:**
# + **2nd_Road_Number** có tới 75% giá trị là 0, chứng tỏ phần lớn vụ tai nạn chỉ xảy ra trên 1 con đường (không phải ngã tư).
# + **Did_Police_Officer_Attend_Scene_of_Accident** từ phần trăm thứ 25 đến 75 đều là 1. Điều này cho thấy trong ít nhất 75% các vụ tai nạn, cảnh sát đã có mặt.
# + **Number_of_Casualties** (Số người thương vong) có trung vị là 1 và trung bình là ~1.35. Điều này khẳng định đa số các vụ tai nạn chỉ có 1 người thương vong. Tuy nhiên, giá trị trung bình cao hơn trung vị cho thấy có tồn tại một số ít vụ tai nạn nghiêm trọng với nhiều nạn nhân, kéo giá trị trung bình lên.
# + **Number_of_Vehicles** (Số phương tiện) có trung vị là 2, cho thấy đặc trưng phổ biến nhất là va chạm giữa hai xe.
# + **Pedestrian_Crossing-Human_Control** và **Pedestrian_Crossing-Physical_Facilities** đều có trung vị bằng 0. Điều này có nghĩa là phần lớn các vụ tai nạn KHÔNG xảy ra tại hoặc gần các khu vực có vạch sang đường, cầu vượt hoặc có nhân viên điều khiển giao thông. Điều này có thể dẫn đến một giả thuyết: tai nạn có xu hướng xảy ra ở những đoạn đường "trống", nơi người tham gia giao thông chủ quan hơn.
# + **Speed_limit** có trung vị = 30 và 75th percentile = 50. Điều này cho thấy phần lớn tai nạn xảy ra trên các tuyến đường trong thành phố (30 mph) hoặc đường chính (50 mph). Giá trị 0 là bất thường, tai nạn có thể xảy ra trong bãi đỗ xe.

# %% [markdown]
# #### **(4) Các tính chất thống kê trên dữ liệu phân loại**
# + Count, Unique, Top, Frequency, Data Type.

# %%
# Lọc các cột object
object_accident = Accident.select_dtypes(include=['object'])
description_object = object_accident.describe().T

# Thêm các thông tin bổ sung
description_object['unique_count'] = object_accident.nunique()
description_object['most_frequent_count'] = object_accident.apply(lambda x: x.value_counts().iloc[0])
description_object['most_frequent_percent'] = (description_object['most_frequent_count'] / len(Accident)) * 100
description_object['datatype'] = object_accident.dtypes

# Hiển thị kết quả
display(description_object[['count', 'unique', 'top', 'freq', 'most_frequent_count', 'most_frequent_percent', 'datatype']])
# Out:
#                               count   unique  \
# Accident_Index              2047256  2047256
# 1st_Road_Class              2047256        6
# 2nd_Road_Class              1202984        6
# Accident_Severity           2047256        3
# Carriageway_Hazards           39449        6
# Date                        2047256     4748
# Day_of_Week                 2047256        7
# Junction_Control            2047256        6
# Junction_Detail             2047256       10
# Light_Conditions            2047256        6
# Local_Authority_(District)  2047256      416
# Local_Authority_(Highway)   2047256      207
# LSOA_of_Accident_Location   1902303    35564
# Police_Force                2047256       51
# Road_Surface_Conditions     2047256        6
# Road_Type                   2047256        7
# Special_Conditions_at_Site    52119        8
# Time                        2047100     1439
# Urban_or_Rural_Area         2047256        3
# Weather_Conditions          2047256       10
# InScotland                  2047203        2
#
#                                                             top     freq  \
# Accident_Index                                    2017984122617        1
# 1st_Road_Class                                                A   926729
# 2nd_Road_Class                                     Unclassified   814983
# Accident_Severity                                        Slight  1734548
# Carriageway_Hazards                        Other object on road    16111
# Date                                                 2005-10-21      822
# Day_of_Week                                              Friday   335183
# Junction_Control                       Give way or uncontrolled   988313
# Junction_Detail             Not at junction or within 20 metres   827223
# Light_Conditions                                       Daylight  1496121
# Local_Authority_(District)                           Birmingham    39662
# Local_Authority_(Highway)                                  Kent    57801
# LSOA_of_Accident_Location                             E01000004     2367
# Police_Force                                Metropolitan Police   316234
# Road_Surface_Conditions                                     Dry  1418215
# Road_Type                                    Single carriageway  1527882
# Special_Conditions_at_Site                            Roadworks    23525
# Time                                                      17:00    19960
# Urban_or_Rural_Area                                       Urban  1322339
# Weather_Conditions                           Fine no high winds  1640095
# InScotland                                                   No  1913224
#
#                             most_frequent_count  most_frequent_percent  \
# Accident_Index                                1               0.000049
# 1st_Road_Class                           926729              45.266884
# 2nd_Road_Class                           814983              39.808553
# Accident_Severity                       1734548              84.725506
# Carriageway_Hazards                       16111               0.786956
# Date                                        822               0.040151
# Day_of_Week                              335183              16.372305
# Junction_Control                         988313              48.275008
# Junction_Detail                          827223              40.406427
# Light_Conditions                        1496121              73.079332
# Local_Authority_(District)                39662               1.937325
# Local_Authority_(Highway)                 57801               2.823340
# LSOA_of_Accident_Location                  2367               0.115618
# Police_Force                             316234              15.446725
# Road_Surface_Conditions                 1418215              69.273945
# Road_Type                               1527882              74.630725
# Special_Conditions_at_Site                23525               1.149099
# Time                                      19960               0.974964
# Urban_or_Rural_Area                     1322339              64.590799
# Weather_Conditions                      1640095              80.111867
# InScotland                              1913224              93.453090
#
#                            datatype
# Accident_Index               object
# 1st_Road_Class               object
# 2nd_Road_Class               object
# Accident_Severity            object
# Carriageway_Hazards          object
# Date                         object
# Day_of_Week                  object
# Junction_Control             object
# Junction_Detail              object
# Light_Conditions             object
# Local_Authority_(District)   object
# Local_Authority_(Highway)    object
# LSOA_of_Accident_Location    object
# Police_Force                 object
# Road_Surface_Conditions      object
# Road_Type                    object
# Special_Conditions_at_Site   object
# Time                         object
# Urban_or_Rural_Area          object
# Weather_Conditions           object
# InScotland                   object

# %% [markdown]
# **Nhận xét:**
# + Đa số các vụ tai nạn có mức độ nghiêm trọng thấp. Biến **Accident_Severity** cho thấy một con số áp đảo: 84.7% các vụ tai nạn được phân loại là "Slight" (Nhẹ).
# + **Junction_Detail** cho biết 40.4% tai nạn xảy ra tại vị trí "Not at junction or within 20 metres" (Không tại ngã tư hoặc trong phạm vi 20 mét). Kết hợp với **Junction_Control** (48.3% là "Give way or uncontrolled" - Nhường đường hoặc không được kiểm soát), cho thấy rủi ro lớn lại nằm ở những đoạn đường thông thường, nơi người tham gia giao thông có thể chủ quan.
# + **Road_Surface_Conditions** 69.3% là "Dry" (Khô ráo), **Light_Conditions** 73.1% xảy ra vào ban ngày ("Daylight") và **Weather_Conditions** 80.1% xảy ra khi trời "Fine no high winds" (Đẹp, không có gió mạnh). Điều này đi ngược với suy nghĩ thông thường rằng tai nạn hay xảy ra khi trời mưa, đường trơn, hoặc trong đêm tối. Thực tế dữ liệu cho thấy, phần lớn tai nạn xảy ra trong những điều kiện thuận lợi nhất. Điều này hướng sự chú ý vào các yếu tố như sự mất tập trung, tốc độ, hoặc vi phạm luật giao thông trong điều kiện bình thường, thay vì đổ lỗi cho thời tiết hay tầm nhìn.
# + **Urban_or_Rural_Area** 64.6% các vụ tai nạn xảy ra ở khu vực "Urban". Điều này là hợp lý khi xét đến mật độ phương tiện và người tham gia giao thông ở thành phố luôn cao hơn nông thôn. Nó cũng giải thích cho việc giới hạn tốc độ phổ biến là 30 mph.
# + **Carriageway_Hazards** (Chướng ngại vật trên đường): Chỉ có 39,449/2,047,256 bản ghi có thông tin (~1.9%). Điều này ngụ ý rằng trong 98% các vụ tai nạn, không có chướng ngại vật nào được báo cáo.
# + **Special_Conditions_at_Site** (Điều kiện đặc biệt tại hiện trường): Tỷ lệ có thông tin còn thấp hơn (~2.5%). Điều này không hẳn là dữ liệu "xấu", phần lớn tai nạn xảy ra trong những điều kiện đường xá bình thường, không có gì đặc biệt. Các biến này hầu như chỉ được điền vào khi có sự kiện bất thường như "Roadworks" (Công trường đang thi công).

# %% [markdown]
# ### **3.2. File Vehicle_Information**

# %% [markdown]
# #### **(1) Hiển thị một số thông tin về dữ liệu**
# + Số dòng, số cột của dữ liệu
# + 2 dòng đầu và 2 dòng cuối của bảng dữ liệu
# + Thông tin chung về dữ liệu

# %%
# shape
print(f'+ Shape: {Vehicle.shape}')
# head, tail
print(f'+ Contents: ')
display(Vehicle.head(2))
display(Vehicle.tail(2))
# info
Vehicle.info()
# Out:
# + Shape: (2177205, 24)
# + Contents:
#   Accident_Index Age_Band_of_Driver  Age_of_Vehicle Driver_Home_Area_Type  \
# 0  200401BS00001            26 - 35             3.0            Urban area
# 1  200401BS00002            26 - 35             NaN            Urban area
#
#    Driver_IMD_Decile  Engine_Capacity_.CC. Hit_Object_in_Carriageway  \
# 0                4.0                1588.0                       NaN
# 1                3.0                   NaN                       NaN
#
#   Hit_Object_off_Carriageway     Journey_Purpose_of_Driver  \
# 0                        NaN  Data missing or out of range
# 1                        NaN  Data missing or out of range
#
#               Junction_Location  ... Skidding_and_Overturning  \
# 0  Data missing or out of range  ...                      NaN
# 1  Data missing or out of range  ...                      NaN
#
#   Towing_and_Articulation Vehicle_Leaving_Carriageway  \
# 0     No tow/articulation   Did not leave carriageway
# 1     No tow/articulation   Did not leave carriageway
#
#   Vehicle_Location.Restricted_Lane  Vehicle_Manoeuvre Vehicle_Reference  \
# 0                              0.0  Going ahead other                 2
# 1                              0.0  Going ahead other                 1
#
#   Vehicle_Type   Was_Vehicle_Left_Hand_Drive X1st_Point_of_Impact  Year
# 0          109  Data missing or out of range                Front  2004
# 1          109  Data missing or out of range                Front  2004
#
# [2 rows x 24 columns]
#         Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 2177203  2016984131316            16 - 20            13.0
# 2177204  2016984133416            46 - 55             5.0
#
#         Driver_Home_Area_Type  Driver_IMD_Decile  Engine_Capacity_.CC.  \
# 2177203            Urban area                6.0                1796.0
# 2177204            Urban area                NaN                2184.0
#
#         Hit_Object_in_Carriageway Hit_Object_off_Carriageway  \
# 2177203                       NaN                       Tree
# 2177204                       NaN              Wall or fence
#
#         Journey_Purpose_of_Driver                       Junction_Location  \
# 2177203                 Not known  Not at or within 20 metres of junction
# 2177204                 Not known  Not at or within 20 metres of junction
#
#          ... Skidding_and_Overturning Towing_and_Articulation  \
# 2177203  ...                  Skidded     No tow/articulation
# 2177204  ...   Skidded and overturned     No tow/articulation
#
#         Vehicle_Leaving_Carriageway Vehicle_Location.Restricted_Lane  \
# 2177203                     Offside                              0.0
# 2177204                    Nearside                              0.0
#
#          Vehicle_Manoeuvre Vehicle_Reference Vehicle_Type  \
# 2177203  Going ahead other                 1          Car
# 2177204  Going ahead other                 1          Car
#
#          Was_Vehicle_Left_Hand_Drive X1st_Point_of_Impact  Year
# 2177203                           No                Front  2016
# 2177204                           No             Nearside  2016
#
# [2 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2177205 entries, 0 to 2177204
# Data columns (total 24 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Accident_Index                    object
#  1   Age_Band_of_Driver                object
#  2   Age_of_Vehicle                    float64
#  3   Driver_Home_Area_Type             object
#  4   Driver_IMD_Decile                 float64
#  5   Engine_Capacity_.CC.              float64
#  6   Hit_Object_in_Carriageway         object
#  7   Hit_Object_off_Carriageway        object
#  8   Journey_Purpose_of_Driver         object
#  9   Junction_Location                 object
#  10  make                              object
#  11  model                             object
#  12  Propulsion_Code                   object
#  13  Sex_of_Driver                     object
#  14  Skidding_and_Overturning          object
#  15  Towing_and_Articulation           object
#  16  Vehicle_Leaving_Carriageway       object
#  17  Vehicle_Location.Restricted_Lane  float64
#  18  Vehicle_Manoeuvre                 object
#  19  Vehicle_Reference                 int64
#  20  Vehicle_Type                      object
#  21  Was_Vehicle_Left_Hand_Drive       object
#  22  X1st_Point_of_Impact              object
#  23  Year                              int64
# dtypes: float64(4), int64(2), object(18)
# memory usage: 398.7+ MB

# %% [markdown]
# **Thông tin cơ bản của dữ liệu:**
# + Dữ liệu có 24 tính chất (cột) để phân tích.
# + Các giá trị thuộc đa số thuộc kiểu object (chuỗi/text) với 18 cột, 4 kiểu float64 (các cột số thực như tuổi xe, dung tích động cơ), và 2 kiểu int64 (các cột Vehicle_Reference, Year).
# + Tổng số dòng dữ liệu là 2,177,205 bản ghi (phương tiện tham gia tai nạn).
# + Bộ dữ liệu này không có cột phân lớp. Đây là dữ liệu phương tiện tham gia tai nạn, trong đó các cột Vehicle_Type (loại phương tiện), Age_Band_of_Driver (độ tuổi tài xế), và X1st_Point_of_Impact (điểm va chạm đầu tiên) là các biến chính để phân tích.

# %% [markdown]
# #### **(2) Kiểm tra tính toàn vẹn của dữ liệu**
# + Dữ liệu có bị trùng lặp không? Hiển thị dòng bị vi phạm.
# + Dữ liệu có tồn tại giá trị Null/NaN không? Hiển thị dòng bị vi phạm.

# %%
# Kiểm tra dữ liệu trùng lặp
n_duplicated = Vehicle.duplicated().sum()
print(f'- Số dòng trùng lặp: {n_duplicated}')

# Thống kê chi tiết các cột có giá trị missing
print("- Thống kê chi tiết giá trị missing theo cột:")
missing_stats = Vehicle.isnull().sum()
missing_percent = (Vehicle.isnull().sum() / len(Vehicle)) * 100
missing_df = pd.DataFrame({
    'Số lượng missing': missing_stats,
    'Tỷ lệ %': missing_percent
}).sort_values('Số lượng missing', ascending=False)
missing_df = missing_df[missing_df['Số lượng missing'] > 0]
display(missing_df)
# Out:
# - Số dòng trùng lặp: 0
# - Thống kê chi tiết giá trị missing theo cột:
#                                   Số lượng missing    Tỷ lệ %
# Hit_Object_in_Carriageway                  2087824  95.894691
# Hit_Object_off_Carriageway                 1989741  91.389695
# Skidding_and_Overturning                   1898208  87.185543
# Driver_IMD_Decile                           734812  33.750244
# Age_of_Vehicle                              358149  16.449944
# model                                       325331  14.942598
# Engine_Capacity_.CC.                        265861  12.211115
# Propulsion_Code                             245843  11.291679
# make                                        110845   5.091160
# Vehicle_Location.Restricted_Lane              1317   0.060490

# %% [markdown]
# **Nhận xét:**
# + Dữ liệu không có dòng nào bị trùng lặp (0 dòng trùng).
# + Dữ liệu có tồn tại giá trị missing, cụ thể: các cột **Hit_Object_in_Carriageway**, **Hit_Object_off_Carriageway** và **Skidding_and_Overturning** có tỷ lệ missing rất cao (>87%), cần xem xét loại bỏ. Ngoài ra, các cột **Driver_IMD_Decile**, **Age_of_Vehicle**, **model**, **Engine_Capacity_.CC.** và **Propulsion_Code** có tỷ lệ missing khá cao (từ 11% đến 34%). Bên cạnh đó, các cột khác có tỷ lệ missing thấp (<6%) hoặc rất thấp (<0.1%).

# %% [markdown]
# #### **(3) Các tính chất thống kê trên dữ liệu số**
# + Count, Mean, Standard Deviation
# + Minimum Value, 25th Percentile, 50th Percentile (Median), 75th Percentile, Maximum Value

# %%
description_vehicle = Vehicle.select_dtypes(include=['number']).describe().T
display(description_vehicle)
# Out:
#                                       count         mean          std     min  \
# Age_of_Vehicle                    1819056.0     7.108167     4.725886     1.0
# Driver_IMD_Decile                 1442393.0     5.387559     2.821651     1.0
# Engine_Capacity_.CC.              1911344.0  2042.233961  1950.143170     1.0
# Vehicle_Location.Restricted_Lane  2175888.0     0.107304     0.879964     0.0
# Vehicle_Reference                 2177205.0     1.553405     0.775248     1.0
# Year                              2177205.0  2010.934147     3.694375  2004.0
#
#                                      25%     50%     75%      max
# Age_of_Vehicle                       3.0     7.0    10.0    111.0
# Driver_IMD_Decile                    3.0     5.0     8.0     10.0
# Engine_Capacity_.CC.              1299.0  1598.0  1997.0  96000.0
# Vehicle_Location.Restricted_Lane     0.0     0.0     0.0      9.0
# Vehicle_Reference                    1.0     1.0     2.0     91.0
# Year                              2008.0  2011.0  2014.0   2016.0

# %% [markdown]
# **Nhận xét:**
# + **Age_of_Vehicle** (Độ tuổi phương tiện) có trung vị là 7 năm. Điều này cho thấy phần lớn các phương tiện liên quan đến tai nạn có độ tuổi trung bình khoảng 7 năm. Giá trị lớn nhất (111 năm) là một ngoại lệ hiếm gặp, có thể là lỗi dữ liệu hoặc một phương tiện cổ.
# + **Vehicle_Location.Restricted_Lane** (Vị trí xe - Làn đường hạn chế) có tới 75% giá trị là 0. Điều này khẳng định phần lớn các vụ tai nạn KHÔNG xảy ra trong các làn đường hạn chế (như làn bus, làn đường cong).

# %% [markdown]
# #### **(4) Các tính chất thống kê trên dữ liệu phân loại**
# + Count, Unique, Top, Frequency, Data Type.

# %%
# Lọc các cột object
object_accident = Vehicle.select_dtypes(include=['object'])
description_object = object_accident.describe().T

# Thêm các thông tin bổ sung
description_object['unique_count'] = object_accident.nunique()
description_object['most_frequent_count'] = object_accident.apply(lambda x: x.value_counts().iloc[0])
description_object['most_frequent_percent'] = (description_object['most_frequent_count'] / len(Accident)) * 100
description_object['datatype'] = object_accident.dtypes

# Hiển thị kết quả
display(description_object[['count', 'unique', 'top', 'freq', 'most_frequent_count', 'most_frequent_percent', 'datatype']])
# Out:
#                                count   unique  \
# Accident_Index               2177205  1488981
# Age_Band_of_Driver           2177205       12
# Driver_Home_Area_Type        2177205        4
# Hit_Object_in_Carriageway      89381       12
# Hit_Object_off_Carriageway    187464       12
# Journey_Purpose_of_Driver    2177205        8
# Junction_Location            2177205       10
# make                         2066360      535
# model                        1851874    35723
# Propulsion_Code              1931362       12
# Sex_of_Driver                2177205        4
# Skidding_and_Overturning      278997        6
# Towing_and_Articulation      2177205        7
# Vehicle_Leaving_Carriageway  2177205       10
# Vehicle_Manoeuvre            2177205       19
# Vehicle_Type                 2177205       24
# Was_Vehicle_Left_Hand_Drive  2177205        3
# X1st_Point_of_Impact         2177205        6
#
#                                                                 top     freq  \
# Accident_Index                                        2013460234852       53
# Age_Band_of_Driver                                          26 - 35   450531
# Driver_Home_Area_Type                                    Urban area  1436598
# Hit_Object_in_Carriageway                                      Kerb    34354
# Hit_Object_off_Carriageway                   Other permanent object    56640
# Journey_Purpose_of_Driver                                 Not known   834626
# Junction_Location            Not at or within 20 metres of junction   808108
# make                                                       VAUXHALL   239650
# model                                                       MISSING    11877
# Propulsion_Code                                              Petrol  1143097
# Sex_of_Driver                                                  Male  1468081
# Skidding_and_Overturning                                    Skidded   199825
# Towing_and_Articulation                         No tow/articulation  2136394
# Vehicle_Leaving_Carriageway               Did not leave carriageway  1922892
# Vehicle_Manoeuvre                                 Going ahead other   994636
# Vehicle_Type                                                    Car  1528628
# Was_Vehicle_Left_Hand_Drive                                      No  2045375
# X1st_Point_of_Impact                                          Front  1060289
#
#                              most_frequent_count  most_frequent_percent  \
# Accident_Index                                53               0.002589
# Age_Band_of_Driver                        450531              22.006579
# Driver_Home_Area_Type                    1436598              70.171879
# Hit_Object_in_Carriageway                  34354               1.678051
# Hit_Object_off_Carriageway                 56640               2.766630
# Journey_Purpose_of_Driver                 834626              40.768033
# Junction_Location                         808108              39.472738
# make                                      239650              11.705913
# model                                      11877               0.580142
# Propulsion_Code                          1143097              55.835567
# Sex_of_Driver                            1468081              71.709693
# Skidding_and_Overturning                  199825               9.760626
# Towing_and_Articulation                  2136394             104.354023
# Vehicle_Leaving_Carriageway              1922892              93.925332
# Vehicle_Manoeuvre                         994636              48.583861
# Vehicle_Type                             1528628              74.667164
# Was_Vehicle_Left_Hand_Drive              2045375              99.908121
# X1st_Point_of_Impact                     1060289              51.790738
#
#                             datatype
# Accident_Index                object
# Age_Band_of_Driver            object
# Driver_Home_Area_Type         object
# Hit_Object_in_Carriageway     object
# Hit_Object_off_Carriageway    object
# Journey_Purpose_of_Driver     object
# Junction_Location             object
# make                          object
# model                         object
# Propulsion_Code               object
# Sex_of_Driver                 object
# Skidding_and_Overturning      object
# Towing_and_Articulation       object
# Vehicle_Leaving_Carriageway   object
# Vehicle_Manoeuvre             object
# Vehicle_Type                  object
# Was_Vehicle_Left_Hand_Drive   object
# X1st_Point_of_Impact          object

# %% [markdown]
# **Nhận xét:**
# + **Age_Band_of_Driver** (Độ tuổi tài xế) cho thấy nhóm "26 - 35" là phổ biến nhất, chiếm 22.01%. Điều này chỉ ra rằng các tài xế trẻ và trung niên có liên quan đến tai nạn nhiều hơn các nhóm tuổi khác.
# + **Driver_Home_Area_Type** (Khu vực sinh sống của tài xế) có tới 70.17% giá trị là "Urban area". Phát hiện này hoàn toàn phù hợp và củng cố cho nhận định trước đó rằng tai nạn chủ yếu xảy ra ở khu vực đô thị.
# + **Sex_of_Driver** (Giới tính tài xế) cho thấy nam giới ("Male") chiếm đa số tuyệt đối (71.71%) trong số các tài xế liên quan đến tai nạn.
# + **Skidding_and_Overturning** (Trượt bánh và Lật xe) cho thấy trong số ít các vụ có thông tin, "Skidded" (Trượt bánh) là hiện tượng phổ biến nhất (9.76%). Tuy nhiên, tỷ lệ missing cực cao (~87%) của biến này cần được lưu ý.
# + **Vehicle_Leaving_Carriageway** (Phương tiện rời khỏi lòng đường) cho thấy đa phần (93.93%) "Did not leave carriageway" (Không rời khỏi lòng đường). Điều này cho thấy phần lớn va chạm xảy ra trong phạm vi lòng đường.
# + **Was_Vehicle_Left_Hand_Drive** (Xe có vô lăng bên trái không?) cho thấy gần như tuyệt đối (99.91%) các phương tiện là "No" (Không, tức là vô lăng bên phải), phù hợp với luật giao thông ở Vương quốc Anh.
# + **X1st_Point_of_Impact** (Điểm va chạm đầu tiên) cho thấy "Front" (Đầu xe) là điểm va chạm phổ biến nhất (51.79%), phù hợp với các vụ va chạm trực diện hoặc đâm từ phía sau.

# %% [markdown]
# ##**4. Tiền xử lí dữ liệu (Data Preprocessing)**

# %%
# Tạo dataset_clean để lưu
accidents_clean = Accident.copy()
vehicle_clean = Vehicle.copy()

# %% [markdown]
# ### **Bước 1. Xác định phạm vi phân tích**

# %% [markdown]
# **- Bộ dữ liệu tai nạn giao thông được thu thập trong giai đoạn 2005–2017. Trong giai đoạn tiền xử lí dữ liệu, phạm vi phân tích được giới hạn từ năm 2010 đến 2017 nhằm đảm bảo tính nhất quán của dữ liệu, phản ánh bối cảnh giao thông gần hơn và giảm độ phức tạp trong phân tích. Dữ liệu giai đoạn trước năm 2010 vẫn được giữ trong tập dữ liệu gốc nhưng không được sử dụng trong phân tích chính.**

# %%
accidents_clean = accidents_clean[accidents_clean['Year'].between(2010, 2017)]

# %% [markdown]
# **- Sau khi giới hạn phạm vi phân tích của bộ dữ liệu từ 2005-2017 còn 2010-2017. Thực hiện lọc dữ liệu phương tiện (Vehicle) theo các vụ tai nạn còn lại (Accident) và chỉ giữ các phương tiện thực sự liên quan đến các vụ tai nạn trong phạm vi phân tích để tránh xử lý dư thừa.**

# %%
# Lấy danh sách Accident_Index sau khi lọc năm
valid_accident_ids = accidents_clean['Accident_Index']

# Lọc Vehicle theo danh sách Accident_Index hợp lệ
vehicle_clean = vehicle_clean[
    vehicle_clean['Accident_Index'].isin(valid_accident_ids)]

# %%
accidents_clean.shape
# Out:
# (1143100, 34)

# %%
vehicle_clean.shape
# Out:
# (1399165, 24)

# %% [markdown]
# **- Kết quả:**
# - Số dòng của Accident giảm từ 2047256 xuống còn 1143100 dòng.
# - Số dòng của Vehicle giảm từ 2.177.205 xuống còn 1.399.165 dòng.

# %% [markdown]
# ### **Bước 2. Loại bỏ cột dư thừa**

# %% [markdown]
# **A. File Accident_Information**

# %%
column_to_drops = ['1st_Road_Class', '1st_Road_Number', '2nd_Road_Class','2nd_Road_Number','Did_Police_Officer_Attend_Scene_of_Accident',
                   'Latitude', 'Longitude','Location_Easting_OSGR', 'Location_Northing_OSGR',
                   'Local_Authority_(District)', 'Local_Authority_(Highway)', 'Police_Force',
                   'LSOA_of_Accident_Location','Pedestrian_Crossing-Human_Control','InScotland',
                   'Pedestrian_Crossing-Physical_Facilities', 'Carriageway_Hazards','Special_Conditions_at_Site']
accidents_clean = accidents_clean.drop(columns = column_to_drops)
print(f"Sau khi xóa: {accidents_clean.shape}")
# Out:
# Sau khi xóa: (1143100, 16)

# %% [markdown]
# **Lí do loại bỏ:**
# - 1st_Road_Class', '1st_Road_Number
# - **2nd_Road_Class** và **2nd_Road_Number**: Hai biến này mô tả đường phụ. Trong dữ liệu tai nạn giao thông, đường chính (1st road) mới là yếu tố quyết định mức độ nguy hiểm. Vì vậy, việc giữ lại không làm tăng giá trị cho phân tích nhưng làm tăng số chiều của dữ liệu.
# - **Did_Police_Officer_Attend_Scene_of_Accident**: Biến này thuộc nhóm thông tin hậu kiểm, được ghi nhận sau khi tai nạn xảy ra. Nó không phải yếu tố ảnh hưởng đến việc tai nạn xảy ra, nên không phù hợp cho phân tích nguyên nhân.
# - **Latitude**, **Longitude**, **Location_Easting_OSGR**, **Location_Northing_OSGR**: chứa tọa độ thô, không hữu ích cho EDA.
# - **LSOA_of_Accident_Location**: mã vùng thống kê, khó diễn giải và không cần thiết cho EDA tổng quan.
# - Local_Authority_(District)', 'Local_Authority_(Highway)', 'Police_Force'
# - **Pedestrian_Crossing-Physical_Facilities** và **Pedestrian_Crossing-Human_Control**: Mức độ ảnh hưởng cũng nhỏ so với các yếu tố quan trọng như thời tiết, loại đường, tốc độ, giao lộ,... nên loại bỏ để giảm nhiễu.
# - **InScotland**: Biến này chỉ biểu thị một cờ nhị phân (Scotland = 1). Tuy nhiên, các biến địa lý khác (Local Authority, District) đã bao phủ khu vực đầy đủ hơn. Vì tính thông tin trùng lặp, biến này được loại bỏ.
# - **Carriageway_Hazards** (98.07% missing) và **Special_Conditions_at_Site** (97.45%): tỷ lệ thiếu gần 100%, gần như không sử dụng được cho phân tích, giữ lại chỉ tạo nhiễu.

# %% [markdown]
# **B. File Vehicle_Information**

# %%
column_to_drops = ['make','model','Propulsion_Code','Hit_Object_in_Carriageway', 'Hit_Object_off_Carriageway',
                   'Skidding_and_Overturning', 'Was_Vehicle_Left_Hand_Drive','Vehicle_Location.Restricted_Lane',
                   'Vehicle_Reference','Junction_Location','Towing_and_Articulation', 'Year', 'Driver_IMD_Decile',
                   'Driver_Home_Area_Type','Journey_Purpose_of_Driver','X1st_Point_of_Impact']
vehicle_clean = vehicle_clean.drop(columns = column_to_drops)
print(f"Sau khi xóa: {vehicle_clean.shape}")
# Out:
# Sau khi xóa: (1399165, 8)

# %% [markdown]
# **Lí do loại bỏ:**
# - **Hit_Object_in_Carriageway** (95.89% missing), **Hit_Object_off_Carriageway** (91.38%) và **Skidding_and_Overturning** (87.18%): Ba biến này gần như trống hoàn toàn. Việc giữ lại không mang lại giá trị phân tích và chỉ gây tăng kích thước dữ liệu.
# - **make**, **model**, **Propulsion_Code**: Dữ liệu chi tiết kỹ thuật của xe, đây cũng không phải yếu tố chính ảnh hưởng đến tai nạn trong phân tích hành vi hoặc điều kiện đường sá. Do đó các biến này được loại bỏ để tránh tăng số chiều dữ liệu
# - **Was_Vehicle_Left_Hand_Drive**: Biến này xuất hiện với tần suất cực thấp, nên đóng góp thông tin rất nhỏ. Các biến hiếm thường được loại bỏ vì dễ gây mất cân bằng và không mang lại insight đáng kể về cơ chế gây tai nạn.
# - **Vehicle_Location.Restricted_Lane**: Biến này phản ánh xe có di chuyển trong làn giới hạn hay không. Vì biến này không mang lại giá trị phân tích rõ ràng và có thể loại bỏ để tinh gọn dữ liệu.
# - Vehicle_Reference
# - Junction_Location
# - Towing_and_Articulation
# - Year
# - Driver_IMD_Decile
# - Driver_Home_Area_Type
# - Journey_Purpose_of_Driver
# - X1st_Point_of_Impact

# %% [markdown]
# ###**Bước 3: Hợp nhất dữ liệu**

# %% [markdown]
# **- Do mỗi vụ tai nạn có thể liên quan đến nhiều phương tiện khác nhau, bảng Vehicle cần được tổng hợp theo khóa Accident_Index để đảm bảo mỗi bản ghi trong dataset cuối cùng đại diện cho một vụ tai nạn duy nhất, tránh hiện tượng nhân bản bản ghi khi hợp nhất dữ liệu, đồng thời vẫn giữ được thông tin đặc trưng của các phương tiện liên quan đến mỗi vụ tai nạn. Quá trình tổng hợp, sẽ áp dụng theo quy ước:**
#
#   - Đối với các biến phân loại (categorical):
# Giá trị đại diện được xác định bằng mode (giá trị xuất hiện nhiều nhất), nhằm phản ánh đặc điểm phổ biến nhất của các phương tiện liên quan trong cùng một vụ tai nạn.
#   - Đối với các biến dạng số (numerical):
# Sử dụng median (thay vì mean) vì nó không bị ảnh hưởng bởi các giá trị ngoại lai, đồng thời phản ánh xu hướng trung tâm ổn định hơn của dữ liệu.

# %%
import polars as pl

# Đổi tên cột để sử dụng
vehicle_clean = vehicle_clean.rename(columns={'Engine_Capacity_.CC.':'Engine_Capacity_CC'})
df = pl.from_pandas(vehicle_clean)

# Aggregate theo Accident_Index
vehicle_agg_pl = df.group_by("Accident_Index").agg([
    pl.col("Vehicle_Type").mode().first().alias("Vehicle_Type"),
    pl.col("Vehicle_Manoeuvre").mode().first().alias("Vehicle_Manoeuvre"),
    pl.col("Vehicle_Leaving_Carriageway").mode().first().alias("Vehicle_Leaving_Carriageway"),
    pl.col("Age_Band_of_Driver").mode().first().alias("Age_Band_of_Driver"),
    pl.col("Sex_of_Driver").mode().first().alias("Sex_of_Driver"),
    pl.col("Age_of_Vehicle").median().alias("Age_of_Vehicle"),
    pl.col("Engine_Capacity_CC").median().alias("Engine_Capacity_CC")
])

vehicle_agg = vehicle_agg_pl.to_pandas()
print(f"Hoàn thành! Kết quả có {len(vehicle_agg)} dòng")
# Out:
# Hoàn thành! Kết quả có 875297 dòng

# %% [markdown]
# **- Sau khi đã tổng hợp dữ liệu phương tiện theo Accident_Index, chúng ta có bảng vehicle_agg với mỗi dòng đại diện cho một vụ tai nạn duy nhất đồng thời chứa thông tin tổng hợp của các phương tiện liên quan.**
#
# **- Bước tiếp theo, chúng ta sẽ gộp bảng Accident với bảng Vehicle đã tổng hợp để tạo dataset cuối cùng phục vụ cho phân tích khám phá dữ liệu (EDA) và xây dựng mô hình. Với Khóa chính để merge là Accident_Index, sử dụng phương pháp LEFT JOIN để đảm bảo giữ lại tất cả các vụ tai nạn trong accidents_clean kể cả những vụ không có thông tin phương tiện tương ứng.**

# %%
merged_data = pd.merge(
    accidents_clean, # bảng tai nạn
    vehicle_agg,  # bảng vehicle đã aggregate
    on='Accident_Index',
    how='left'
)

merged_data.info()
display(merged_data.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143100 entries, 0 to 1143099
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Accident_Index               1143100 non-null  object
#  1   Accident_Severity            1143100 non-null  object
#  2   Date                         1143100 non-null  object
#  3   Day_of_Week                  1143100 non-null  object
#  4   Junction_Control             1143100 non-null  object
#  5   Junction_Detail              1143100 non-null  object
#  6   Light_Conditions             1143100 non-null  object
#  7   Number_of_Casualties         1143100 non-null  int64
#  8   Number_of_Vehicles           1143100 non-null  int64
#  9   Road_Surface_Conditions      1143100 non-null  object
#  10  Road_Type                    1143100 non-null  object
#  11  Speed_limit                  1143063 non-null  float64
#  12  Time                         1143044 non-null  object
#  13  Urban_or_Rural_Area          1143100 non-null  object
#  14  Weather_Conditions           1143100 non-null  object
#  15  Year                         1143100 non-null  int64
#  16  Vehicle_Type                 875297 non-null   object
#  17  Vehicle_Manoeuvre            875297 non-null   object
#  18  Vehicle_Leaving_Carriageway  875297 non-null   object
#  19  Age_Band_of_Driver           875297 non-null   object
#  20  Sex_of_Driver                875297 non-null   object
#  21  Age_of_Vehicle               791479 non-null   float64
#  22  Engine_Capacity_CC           811947 non-null   float64
# dtypes: float64(3), int64(3), object(17)
# memory usage: 200.6+ MB
#   Accident_Index Accident_Severity        Date Day_of_Week  \
# 0  201001BS70003            Slight  2010-01-11      Monday
# 1  201001BS70004            Slight  2010-01-11      Monday
# 2  201001BS70006            Slight  2010-01-12     Tuesday
# 3  201001BS70007            Slight  2010-01-02    Saturday
# 4  201001BS70008            Slight  2010-01-04      Monday
#
#            Junction_Control          Junction_Detail       Light_Conditions  \
# 0  Give way or uncontrolled  T or staggered junction               Daylight
# 1       Auto traffic signal  T or staggered junction  Darkness - lights lit
# 2       Auto traffic signal  T or staggered junction               Daylight
# 3  Give way or uncontrolled          Mini-roundabout  Darkness - lights lit
# 4       Auto traffic signal               Crossroads  Darkness - lights lit
#
#    Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  ...  \
# 0                     1                   2             Wet or damp  ...
# 1                     1                   1             Wet or damp  ...
# 2                     1                   2                     Dry  ...
# 3                     1                   2                     Dry  ...
# 4                     1                   2             Wet or damp  ...
#
#   Urban_or_Rural_Area     Weather_Conditions  Year  \
# 0               Urban                  Other  2010
# 1               Urban  Raining no high winds  2010
# 2               Urban     Fine no high winds  2010
# 3               Urban     Fine no high winds  2010
# 4               Urban     Fine no high winds  2010
#
#                           Vehicle_Type            Vehicle_Manoeuvre  \
# 0  Van / Goods 3.5 tonnes mgw or under                Turning right
# 1                                  Car            Going ahead other
# 2      Goods over 3.5t. and under 7.5t                 Turning left
# 3                                  Car  Going ahead right-hand bend
# 4                Taxi/Private hire car            Going ahead other
#
#    Vehicle_Leaving_Carriageway Age_Band_of_Driver Sex_of_Driver  \
# 0    Did not leave carriageway            36 - 45        Female
# 1    Did not leave carriageway            46 - 55          Male
# 2    Did not leave carriageway            36 - 45          Male
# 3    Did not leave carriageway            36 - 45        Female
# 4    Did not leave carriageway            46 - 55          Male
#
#   Age_of_Vehicle Engine_Capacity_CC
# 0            1.0             1360.0
# 1            3.0             1870.0
# 2            8.0             3920.0
# 3            9.0             1697.5
# 4            6.0             1372.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ###**Bước 4: Xử lí dữ liệu thiếu (Missing values)**

# %% [markdown]
# **- Kiểm tra các giá trị Missing của biến số:**

# %%
# Lọc các biến số
numerical_cols = merged_data.select_dtypes(include=['float64','int64']).columns

# Thống kê missing chỉ cho biến số
missing_stats = merged_data[numerical_cols].isnull().sum()
missing_percent = (missing_stats / len(merged_data)) * 100

missing_df = pd.DataFrame({
    'Số lượng missing': missing_stats,
    'Tỷ lệ %': missing_percent
}).sort_values('Số lượng missing', ascending=False)

# Chỉ hiển thị những cột có missing
missing_df = missing_df[missing_df['Số lượng missing'] > 0]

display(missing_df)
# Out:
#                     Số lượng missing    Tỷ lệ %
# Age_of_Vehicle                351621  30.760301
# Engine_Capacity_CC            331153  28.969731
# Hour                              56   0.004899
# Speed_limit                       37   0.003237

# %%
# Thống kê chi tiết các cột có giá trị missing
print("- Thống kê chi tiết giá trị missing theo cột:")
missing_stats = merged_data.isnull().sum()
missing_percent = (merged_data.isnull().sum() / len(merged_data)) * 100
missing_df = pd.DataFrame({
    'Số lượng missing': missing_stats,
    'Tỷ lệ %': missing_percent
}).sort_values('Số lượng missing', ascending=False)
missing_df = missing_df[missing_df['Số lượng missing'] > 0]
display(missing_df)
# Out:
# - Thống kê chi tiết giá trị missing theo cột:
#                              Số lượng missing    Tỷ lệ %
# Age_of_Vehicle                         351621  30.760301
# Engine_Capacity_CC                     331153  28.969731
# Sex_of_Driver                          267803  23.427784
# Age_Band_of_Driver                     267803  23.427784
# Vehicle_Manoeuvre                      267803  23.427784
# Vehicle_Type                           267803  23.427784
# Vehicle_Leaving_Carriageway            267803  23.427784
# Time                                       56   0.004899
# Speed_limit                                37   0.003237

# %% [markdown]
# **Thực hiện xử lí các giá trị thiếu (Missing values) theo quy ước:**
#
# - *Tỉ lệ missing >50%: xóa cột*
#
# - *Tỉ lệ mising 5-50%: impute (mean/median).*
#
# - *Tỉ lệ mising <5%: xóa dòng.*

# %%
# Xóa các dòng có missing values
accidents_draft = accidents_clean.dropna(subset=['Time', 'Speed_limit', '1st_Road_Number'])

# Kiểm tra lại missing values
print("Missing values sau khi xóa:")
missing_after = accidents_draft[['Time', 'Speed_limit', '1st_Road_Number']].isnull().sum()
print(missing_after)
# Out:
# Missing values sau khi xóa:
# Time               0
# Speed_limit        0
# 1st_Road_Number    0
# dtype: int64

# %% [markdown]
# **- Kiểm tra các giá trị Missing của biến phân loại:**

# %%
categorical_cols = accidents_clean.select_dtypes(include=['object']).columns
total_records = len(accidents_clean)

special_found = False

for col in categorical_cols:
    col_series = accidents_clean[col].astype(str).str.strip()
    col_series_lower = col_series.str.lower()

    # Đếm 3 loại special value
    data_missing_count = (col_series == "Data missing or out of range").sum()
    unknown_count = (col_series_lower == "unknown").sum()
    unallocated_count = (col_series_lower == "unallocated").sum()

    # Nếu cột không có special → bỏ qua
    if data_missing_count + unknown_count + unallocated_count == 0:
        continue

    # Print header (chỉ 1 lần)
    if not special_found:
        print(f"{'CỘT':<35} {'GIÁ TRỊ':<40} {'SỐ LƯỢNG':>10}   {'TỶ LỆ':>7}")
        print("-"*100)
        special_found = True

    # In từng giá trị
    if data_missing_count > 0:
        print(f"{col:<35} {'Data missing or out of range':<40} {data_missing_count:>10,}   {data_missing_count/total_records*100:>6.4f}%")

    if unknown_count > 0:
        print(f"{col:<35} {'Unknown':<40} {unknown_count:>10,}   {unknown_count/total_records*100:>6.4f}%")

    if unallocated_count > 0:
        print(f"{col:<35} {'Unallocated':<40} {unallocated_count:>10,}   {unallocated_count/total_records*100:>6.4f}%")

    print("-"*100)
# Out:
# CỘT                                 GIÁ TRỊ                                    SỐ LƯỢNG     TỶ LỆ
# ----------------------------------------------------------------------------------------------------
# Junction_Control                    Data missing or out of range                754,206   36.8434%
# ----------------------------------------------------------------------------------------------------
# Junction_Detail                     Data missing or out of range                    733   0.0358%
# ----------------------------------------------------------------------------------------------------
# Light_Conditions                    Data missing or out of range                     11   0.0005%
# ----------------------------------------------------------------------------------------------------
# Road_Surface_Conditions             Data missing or out of range                  5,138   0.2510%
# ----------------------------------------------------------------------------------------------------
# Road_Type                           Data missing or out of range                      1   0.0000%
# Road_Type                           Unknown                                      14,384   0.7027%
# ----------------------------------------------------------------------------------------------------
# Urban_or_Rural_Area                 Unallocated                                     160   0.0078%
# ----------------------------------------------------------------------------------------------------
# Weather_Conditions                  Data missing or out of range                    172   0.0084%
# Weather_Conditions                  Unknown                                      42,506   2.0764%
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Thực hiện xử lí các giá trị thiếu (Missing values) theo quy ước:**
# - *Gom các giá trị không rõ. Bao gồm: Data missing or out of range, Unknown, Other, Other/Not known, Not known  gộp thành một category chung là Missing.*
# - *Tỉ lệ missing >5%: Keep (giữ nguyên category Missing)*
# - *Tỉ lệ mising <5%: Impute (mode).*

# %%
missing_labels = [
    "Data missing or out of range",
    "Unknown"
]
categorical_cols = accidents_clean.select_dtypes(include=['object']).columns
for col in categorical_cols:
    if col == "Urban_or_Rural_Area":
        accidents_clean[col] = accidents_clean[col].replace({
            "Data missing or out of range": "Missing",
            "Unknown": "Missing"
        })
    else:
        accidents_clean[col] = accidents_clean[col].replace(missing_labels, "Missing")

for col in categorical_cols:
    missing_rate = (accidents_clean[col] == "Missing").mean()

    if missing_rate < 0.05:
        # Impute mode
        mode_val = accidents_clean[col].mode()[0]
        accidents_clean[col] = accidents_clean[col].replace("Missing", mode_val)
        print(f"[IMPUTE] {col}: {missing_rate:.2%} → replaced Missing with mode = {mode_val}")
    else:
        print(f"[KEEP] {col}: {missing_rate:.2%} → kept as separate 'Missing' category")
# Out:
# [IMPUTE] Accident_Index: 0.00% → replaced Missing with mode = 200501BS00001
# [IMPUTE] 1st_Road_Class: 0.00% → replaced Missing with mode = A
# [IMPUTE] Accident_Severity: 0.00% → replaced Missing with mode = Slight
# [IMPUTE] Date: 0.00% → replaced Missing with mode = 2005-10-21
# [IMPUTE] Day_of_Week: 0.00% → replaced Missing with mode = Friday
# [KEEP] Junction_Control: 36.84% → kept as separate 'Missing' category
# [IMPUTE] Junction_Detail: 0.04% → replaced Missing with mode = Not at junction or within 20 metres
# [IMPUTE] Light_Conditions: 0.00% → replaced Missing with mode = Daylight
# [IMPUTE] Local_Authority_(District): 0.00% → replaced Missing with mode = Birmingham
# [IMPUTE] Local_Authority_(Highway): 0.00% → replaced Missing with mode = Kent
# [IMPUTE] Police_Force: 0.00% → replaced Missing with mode = Metropolitan Police
# [IMPUTE] Road_Surface_Conditions: 0.25% → replaced Missing with mode = Dry
# [IMPUTE] Road_Type: 0.70% → replaced Missing with mode = Single carriageway
# [IMPUTE] Time: 0.00% → replaced Missing with mode = 17:00
# [IMPUTE] Urban_or_Rural_Area: 0.00% → replaced Missing with mode = Urban
# [IMPUTE] Weather_Conditions: 2.08% → replaced Missing with mode = Fine no high winds

# %%
categorical_cols = vehicle_clean.select_dtypes(include=['object']).columns
total_records = len(vehicle_clean)

special_values = [
    "data missing or out of range",
    "unknown",
    "not known",
    "other/not known (2005-10)",
    "other"
]

special_found = False

for col in categorical_cols:

    col_series = vehicle_clean[col].astype(str).str.strip()
    col_series_lower = col_series.str.lower()

    counts = {}

    # Đếm từng loại special value
    for sv in special_values:
        count = (col_series_lower == sv).sum()
        if count > 0:
            counts[sv] = count

    if len(counts) == 0:
        continue

    # In header (chỉ 1 lần)
    if not special_found:
        print(f"\n{'CỘT':<35} {'GIÁ TRỊ':<45} {'SỐ LƯỢNG':>12}   {'TỶ LỆ':>8}")
        print("-" * 105)
        special_found = True

    # In từng loại missing của cột đó
    for sv, count in counts.items():
        percent = (count / total_records) * 100
        print(f"{col:<35} {sv:<45} {count:>12,}   {percent:>7.4f}%")

    print("-" * 105)
# Out:
# CỘT                                 GIÁ TRỊ                                           SỐ LƯỢNG      TỶ LỆ
# ---------------------------------------------------------------------------------------------------------
# Age_Band_of_Driver                  data missing or out of range                       171,052    7.8565%
# ---------------------------------------------------------------------------------------------------------
# Driver_Home_Area_Type               data missing or out of range                       334,344   15.3566%
# ---------------------------------------------------------------------------------------------------------
# Journey_Purpose_of_Driver           data missing or out of range                       133,560    6.1345%
# Journey_Purpose_of_Driver           not known                                          834,626   38.3347%
# Journey_Purpose_of_Driver           other/not known (2005-10)                          555,726   25.5247%
# Journey_Purpose_of_Driver           other                                               32,965    1.5141%
# ---------------------------------------------------------------------------------------------------------
# Junction_Location                   data missing or out of range                       122,612    5.6316%
# ---------------------------------------------------------------------------------------------------------
# Sex_of_Driver                       data missing or out of range                            68    0.0031%
# Sex_of_Driver                       not known                                           76,051    3.4931%
# ---------------------------------------------------------------------------------------------------------
# Towing_and_Articulation             data missing or out of range                         1,176    0.0540%
# ---------------------------------------------------------------------------------------------------------
# Vehicle_Leaving_Carriageway         data missing or out of range                         1,218    0.0559%
# ---------------------------------------------------------------------------------------------------------
# Vehicle_Manoeuvre                   data missing or out of range                         1,368    0.0628%
# ---------------------------------------------------------------------------------------------------------
# Vehicle_Type                        data missing or out of range                           401    0.0184%
# ---------------------------------------------------------------------------------------------------------
# X1st_Point_of_Impact                data missing or out of range                         2,771    0.1273%
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Thực hiện xử lí các giá trị thiếu (Missing values) theo quy ước:**
# - *Gom các giá trị không rõ. Bao gồm: Data missing or out of range, Unknown, Other, Other/Not known, Not known  gộp thành một category chung là Missing.*
# - *Tỉ lệ missing >5%: Keep (giữ nguyên category Missing)*
# - *Tỉ lệ mising <5%: Impute (mode).*

# %%
missing_labels = [
    "Data missing or out of range",
    "Unknown",
    "Not known",
    "Other",
    "Other/Not known (2005-10)",
    "Unallocated"
]

categorical_cols = vehicle_clean.select_dtypes(include=['object']).columns

for col in categorical_cols:
    vehicle_clean[col] = vehicle_clean[col].astype(str).str.strip()
    vehicle_clean[col] = vehicle_clean[col].replace(
        {label: "Missing" for label in missing_labels}
    )

# Impute
for col in categorical_cols:
    missing_rate = (vehicle_clean[col] == "Missing").mean()

    if missing_rate < 0.05:
        # Impute bằng mode
        mode_val = vehicle_clean[col].mode()[0]
        vehicle_clean[col] = vehicle_clean[col].replace("Missing", mode_val)
        print(f"[IMPUTE] {col}: {missing_rate:.2%} → replaced Missing with mode = {mode_val}")
    else:
        # Giữ Missing
        print(f"[KEEP] {col}: {missing_rate:.2%} → kept as separate 'Missing' category")
# Out:
# [IMPUTE] Accident_Index: 0.00% → replaced Missing with mode = 2013460234852
# [KEEP] Age_Band_of_Driver: 7.86% → kept as separate 'Missing' category
# [KEEP] Driver_Home_Area_Type: 15.36% → kept as separate 'Missing' category
# [KEEP] Journey_Purpose_of_Driver: 71.51% → kept as separate 'Missing' category
# [KEEP] Junction_Location: 5.63% → kept as separate 'Missing' category
# [IMPUTE] Sex_of_Driver: 3.50% → replaced Missing with mode = Male
# [IMPUTE] Towing_and_Articulation: 0.05% → replaced Missing with mode = No tow/articulation
# [IMPUTE] Vehicle_Leaving_Carriageway: 0.06% → replaced Missing with mode = Did not leave carriageway
# [IMPUTE] Vehicle_Manoeuvre: 0.06% → replaced Missing with mode = Going ahead other
# [IMPUTE] Vehicle_Type: 0.02% → replaced Missing with mode = Car
# [IMPUTE] X1st_Point_of_Impact: 0.13% → replaced Missing with mode = Front

# %% [markdown]
# ### **Bước 5. Phát hiện và xử lí outliers**

# %% [markdown]
# **A. File Accident_Information**

# %%
num_cols = ['Number_of_Casualties', 'Number_of_Vehicles']
sns.set(style='darkgrid')
fig, axes = plt.subplots(2, 1, figsize=(8, 6))

for ax, col in zip(axes, num_cols):
    # Tính toán outlier cho từng biến
    Q1 = accidents_clean[col].quantile(0.25)
    Q3 = accidents_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Đếm số lượng outlier
    outlier_count = accidents_clean[
        (accidents_clean[col] < lower_bound) |
        (accidents_clean[col] > upper_bound)
    ].shape[0]

    total_count = accidents_clean.shape[0]
    outlier_percentage = (outlier_count / total_count) * 100

    # Vẽ boxplot
    bp = accidents_clean.boxplot(column=col, grid=False, vert=False, ax=ax)
    ax.text(-0.25, 0.35, f'Outlier: {outlier_percentage:.2f}%',
            transform=ax.transAxes, fontsize=12,
            verticalalignment='center', horizontalalignment='left')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Nhận xét:**
# + Với biến **Number_of_Casualties(Outlier: 22.99%)** đa số các vụ tai nạn đều có số thương vong rất thấp, thường chỉ 1-2 người. Điều này cho thấy hầu hết là các sự cố nhỏ lẻ. Tuy nhiên, vẫn tồn tại một số ít trường hợp có số thương vong rất cao lên đến 93 nạn nhân, dù tỷ lệ outlier cao nhưng các trường hợp này là thật trong thực tế (vụ tai nạn nghiêm trọng, tai nạn hàng loạt).
# + Phân phối của biến **Number_of_Vehicles(Outlier: 2.29%)** cho thấy đa phần là các vụ va chạm đơn giản, chỉ liên quan từ 1-2 phương tiện. Tuy nhiên, sự xuất hiện của các điểm ngoại lai với số xe lớn (67 phương tiện) cho thấy các điểm ngoại lai này phản ánh đúng hiện tượng tai nạn liên hoàn.
# + Các outlier này nên được giữ lại vì mang thông tin giá trị về các tình huống đặc biệt trong dữ liệu.

# %% [markdown]
# **B. File Vehicle_Information**

# %%
num_cols = ['Age_of_Vehicle', 'Engine_Capacity_.CC.', 'Vehicle_Reference']
sns.set(style='darkgrid')
fig, axes = plt.subplots(3, 1, figsize=(10, 8))

for ax, col in zip(axes, num_cols):
    # Tính toán outlier cho từng biến
    Q1 = vehicle_clean[col].quantile(0.25)
    Q3 = vehicle_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Đếm số lượng outlier
    outlier_count = vehicle_clean[
        (vehicle_clean[col] < lower_bound) |
        (vehicle_clean[col] > upper_bound)
    ].shape[0]

    total_count = vehicle_clean.shape[0]
    outlier_percentage = (outlier_count / total_count) * 100

    # Vẽ boxplot
    bp = vehicle_clean.boxplot(column=col, grid=False, vert=False, ax=ax)
    ax.text(-0.2, 0.35, f'Outlier: {outlier_percentage:.2f}%',
            transform=ax.transAxes, fontsize=12,
            verticalalignment='center', horizontalalignment='left')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Nhận xét:**
# + Biến **Age_of_Vehicle** (Outlier: 2.39%) phân phối khá tập trung, với độ tuổi trung bình của phương tiện là 7.1 năm và 75% phương tiện có tuổi đời dưới 10 năm. Tuy nhiên, tồn tại các giá trị ngoại lai lên đến 111 năm - đây rõ ràng là các giá trị bất thường vì không thể có xe cộ lưu thông với tuổi đời cao như vậy. Cần xử lí các giá trị outlier này.
# + Biến **Engine_Capacity_CC.**(Outlier: 12.22%) có phân phối khá rộng với dung tích động cơ trung bình khoảng 2,042 CC. Tuy nhiên, sự hiện diện của giá trị cực đại 96,000 CC là rõ ràng bất thường - đây có thể là lỗi nhập liệu. Với tỷ lệ outlier khá cao 10.49%, cần kiểm tra chi tiết các giá trị này để điều chỉnh.
# + Biến **Vehicle_Reference** (Outlier: 1.85%). Đây là biến tham chiếu phương tiện với phân phối khá tập trung (75% giá trị từ 1-2). Giá trị tối đa 91 có thể đại diện cho các vụ tai nạn đặc biệt nghiêm trọng với nhiều phương tiện liên quan. Với tỷ lệ outlier 1.85% tương đối thấp, giữ nguyên các giá trị này vì có thể chứa thông tin quan trọng về các vụ tai nạn phức tạp.

# %% [markdown]
# **Thực hiện xử lí các giá trị Outliers bất thường của 2 biến **Age_of_Vehicle** và **Engine_Capacity_.CC. theo quy ước sử dụng IQR Capping:****
# + lower bound = Q1 - 1.5 * IQR
# + upper bound = Q3 + 1.5 * IQR
# + Giá trị < lower bound → gán bằng lower bound
# + Giá trị > upper bound → gán bằng upper bound

# %%
num_cols_cap = ['Age_of_Vehicle', 'Engine_Capacity_.CC.']

summary_list = []

for col in num_cols_cap:
    Q1 = vehicle_clean[col].quantile(0.25)
    Q3 = vehicle_clean[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    print(f"Column: {col}")
    print(f"Lower bound: {lower_bound:.2f}, Upper bound: {upper_bound:.2f}")

    # Capping
    vehicle_clean[col] = np.where(
        vehicle_clean[col] < lower_bound, lower_bound,
        np.where(vehicle_clean[col] > upper_bound, upper_bound, vehicle_clean[col])
    )

    # Lưu summary sau capping để hiển thị trong bảng
    desc = vehicle_clean[col].describe()
    summary_list.append({
        "Variable": col,
        "Count": desc["count"],
        "Mean": desc["mean"],
        "Std": desc["std"],
        "Min": desc["min"],
        "25%": desc["25%"],
        "50%": desc["50%"],
        "75%": desc["75%"],
        "Max": desc["max"]
    })

summary_df = pd.DataFrame(summary_list)
display(summary_df)
# Out:
# Column: Age_of_Vehicle
# Lower bound: -3.50, Upper bound: 16.50
# Column: Engine_Capacity_.CC.
# Lower bound: 407.50, Upper bound: 2947.50
#                Variable      Count         Mean         Std    Min     25%  \
# 0        Age_of_Vehicle  2177205.0     6.995682    3.966469    1.0     4.0
# 1  Engine_Capacity_.CC.  2177205.0  1686.732473  589.537044  407.5  1360.0
#
#       50%     75%     Max
# 0     7.0     9.0    16.5
# 1  1598.0  1995.0  2947.5

# %% [markdown]
# ###**Bước 6: Chuyển đổi kiểu dữ liệu**

# %% [markdown]
# **Mục tiêu:** Chuẩn hóa các cột liên quan đến thời gian để phục vụ cho phân
# tích và feature engineering.

# %%
# Chuyển Date từ string → datetime
merged_data['Date'] = pd.to_datetime(merged_data['Date'], errors='coerce')

# Chuyển Time → Hour (numeric)
merged_data['Hour'] = pd.to_datetime(merged_data['Time'], format='%H:%M', errors='coerce').dt.hour

# %% [markdown]
# **Mô tả:**
# + Cột Date được chuyển từ chuỗi sang định dạng datetime để Pandas có thể nhận diện ngày tháng, từ đó dễ dàng tách ra năm, tháng, ngày hoặc tính toán khoảng thời gian.
# + Đồng thời, cột Time được chuyển thành một cột số Hour trích xuất giờ trong ngày, thuận tiện cho việc phân loại các khung giờ như buổi sáng, buổi trưa, chiều, tối và ban đêm. Việc chuyển đổi này giúp dữ liệu thời gian trở nên nhất quán, giảm rủi ro lỗi và chuẩn bị tốt cho các bước phân tích tiếp theo.

# %% [markdown]
# ### **Bước 7: Feature Engineering cơ bản**

# %% [markdown]
# **Mục tiêu:** nhằm tạo ra các biến mới có ý nghĩa từ các cột thời gian để hỗ trợ phân tích. Việc tạo các biến này không chỉ làm giàu thông tin cho dữ liệu mà còn hỗ trợ trực quan hóa và mô hình hóa sau này, đồng thời giúp phát hiện các xu hướng và đặc điểm ẩn trong dữ liệu tai nạn.

# %%
# Tách Date thành Year, Month, Day, Day_of_week
merged_data['Month'] = merged_data['Date'].dt.month
merged_data['Day'] = merged_data['Date'].dt.day

# Tạo biến Time_period theo Hour
def assign_time_period(hour):
    if pd.isna(hour):
        return None
    if 5 <= hour < 10:
        return 'Sáng sớm'
    elif 10 <= hour < 15:
        return 'Ban ngày'
    elif 15 <= hour < 19:
        return 'Chiều tối'
    elif 19 <= hour < 23:
        return 'Tối'
    else:
        return 'Khuya'

merged_data['Time_period'] = merged_data['Hour'].apply(assign_time_period)

# Tạo biến Season theo Month
def assign_season(month):
    if pd.isna(month):
        return None
    if month in [3, 4, 5]:
        return 'Mùa xuân'
    elif month in [6, 7, 8]:
        return 'Mùa hạ'
    elif month in [9, 10, 11]:
        return 'Mùa thu'
    else:
        return 'Mùa đông'

merged_data['Season'] = merged_data['Month'].apply(assign_season)

# %% [markdown]
# **Mô tả:**
# + Cột **Date** đã chuẩn hóa, ta tách ra các thành phần gồm năm (**Year**), tháng (**Month**), ngày (**Day**) và ngày trong tuần (**Day_of_week**) để nắm được xu hướng theo từng mốc thời gian.
# + Đồng thời, dựa trên cột **Hour** trích xuất từ cột **Time**, ta phân loại giờ trong ngày thành các khung thời gian có ý nghĩa như “Sáng sớm”, “Ban ngày”, “Chiều tối”, “Tối” và “Khuya”, giúp phân tích tai nạn theo thời điểm trong ngày.
# + Bên cạnh đó, từ cột **Month** còn tạo ra biến **Season** để xác định mùa trong năm, phục vụ các phân tích theo mùa vụ. Có một điểm khác biệt rằng, đó là mùa tại Vương quốc Anh khác với Việt Nam: ở Anh, mùa Xuân bắt đầu từ tháng 3, mùa Hạ từ tháng 6, mùa Thu từ tháng 9 và mùa Đông kết thúc vào tháng 2. Việc xác định mùa theo cách này giúp phân tích các xu hướng tai nạn theo mùa phù hợp với bối cảnh khí hậu và thói quen sinh hoạt tại Anh.

# %% [markdown]
# **Kiểm tra bộ dữ liệu tổng hợp sau toàn bộ các bước tiền xử lí dữ liệu:**

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2058196 entries, 0 to 2058195
# Data columns (total 43 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Accident_Index               object
#  1   1st_Road_Class               object
#  2   1st_Road_Number              float64
#  3   Accident_Severity            object
#  4   Date                         datetime64[ns]
#  5   Day_of_Week                  object
#  6   Junction_Control             object
#  7   Junction_Detail              object
#  8   Light_Conditions             object
#  9   Local_Authority_(District)   object
#  10  Local_Authority_(Highway)    object
#  11  Number_of_Casualties         int64
#  12  Number_of_Vehicles           int64
#  13  Police_Force                 object
#  14  Road_Surface_Conditions      object
#  15  Road_Type                    object
#  16  Speed_limit                  float64
#  17  Time                         object
#  18  Urban_or_Rural_Area          object
#  19  Weather_Conditions           object
#  20  Year_x                       int64
#  21  Age_Band_of_Driver           object
#  22  Age_of_Vehicle               float64
#  23  Driver_Home_Area_Type        object
#  24  Driver_IMD_Decile            float64
#  25  Engine_Capacity_.CC.         float64
#  26  Journey_Purpose_of_Driver    object
#  27  Junction_Location            object
#  28  Sex_of_Driver                object
#  29  Towing_and_Articulation      object
#  30  Vehicle_Leaving_Carriageway  object
#  31  Vehicle_Manoeuvre            object
#  32  Vehicle_Reference            int64
#  33  Vehicle_Type                 object
#  34  X1st_Point_of_Impact         object
#  35  Year_y                       int64
#  36  Hour                         int32
#  37  Year                         int32
#  38  Month                        int32
#  39  Day                          int32
#  40  Day_of_week                  int32
#  41  Time_period                  object
#  42  Season                       object
# dtypes: datetime64[ns](1), float64(5), int32(5), int64(5), object(27)
# memory usage: 636.0+ MB

# %% [markdown]
# **TỔNG QUÁT:** Sau khi hoàn tất toàn bộ 6 bước tiền xử lý, bộ dữ liệu tổng hợp (merged_data) hiện có 2.058.196 bản ghi và 43 cột, bao gồm cả các thông tin ban đầu về tai nạn và phương tiện, cũng như các biến mới được tạo từ bước feature engineering. Các biến số còn lại đã được xử lý missing values và outlier, các biến phân loại được chuẩn hóa và một số cột không cần thiết đã được loại bỏ. Bộ dữ liệu lúc này đã đảm bảo đầy đủ thông tin cho việc phân tích EDA và trực quan hóa ở phần tiếp theo.

# %% [markdown]
# ##**5. Phân tích khám phá (EDA) và trực quan hóa dữ liệu (Data Visualization)**

# %% [markdown]
# ###**5.1.Phân tích đơn biến (Univariate Analysis)**

# %% [markdown]
# Đầu tiên, chúng ta sẽ đi tìm hiểu xem xu hướng tai nạn giao thông tại Vương quốc Anh giai đoạn 2005-2017 có những đặc điểm nổi bật nào theo **THỜI GIAN**

# %% [markdown]
# **Câu hỏi đặt ra:** Tai nạn giao thông thay đổi như thế nào qua các năm? Có dấu hiệu tăng hay giảm, và những năm nào nổi bật về số vụ tai nạn?

# %%
plt.figure(figsize=(10,5))
merged_data['Year'].value_counts().sort_index().plot(marker='o', color='dodgerblue')
plt.title("Số vụ tai nạn theo năm")
plt.ylabel("Số vụ tai nạn")
plt.xlabel("Năm")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# **→ Nhận xét:** Từ năm **2005**, số vụ tai nạn bắt đầu một hành trình biến động. Sau giai đoạn chững lại ban đầu, năm **2009** chứng kiến một cú vọt tăng trưởng khủng khiếp, vượt ngưỡng 180.000 vụ. Dù có một đợt giảm nhẹ từ **2011** đến **2013**, sự bình ổn không kéo dài. Cao trào xảy ra vào năm **2015** khi con số này phá kỷ lục lịch sử, chạm mức hơn 260.000 vụ, trước khi hơi hạ nhiệt vào năm **2016**. Tóm lại, đây là một thập kỷ định hình bởi hai cú sốc tăng trưởng lớn, biến mức thấp ban đầu thành mức cao gấp đôi chỉ trong 10 năm.

# %% [markdown]
# Sau khi đã nắm được bức tranh tổng thể về xu hướng tai nạn qua các năm, bước tiếp theo là đi sâu vào cấu trúc bên trong từng năm. ***Câu hỏi đặt ra: trong mỗi năm, mùa nào ghi nhận nhiều tai nạn nhất? Có thể nhận diện được các mùa cao điểm rõ rệt hay không?***

# %%
season_order = ['Mùa xuân','Mùa hạ','Mùa thu','Mùa đông']
season_counts = merged_data['Season'].value_counts().reindex(season_order)

fig, axes = plt.subplots(1, 2, figsize=(14,5))

# Biểu đồ cột (số lượng)
sns.barplot(x=season_counts.index, y=season_counts.values, palette='Blues', ax=axes[0])
axes[0].set_title("Số vụ tai nạn theo mùa")
axes[0].set_ylabel("Số vụ tai nạn")
axes[0].set_xlabel("Mùa")

# Biểu đồ tròn (tỉ lệ)
axes[1].pie(season_counts.values, labels=season_counts.index, autopct='%1.1f%%', startangle=90,
            colors=sns.color_palette("Blues", n_colors=4))
axes[1].set_title("Tỉ lệ tai nạn theo mùa")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3928403797.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=season_counts.index, y=season_counts.values, palette='Blues', ax=axes[0])

# %% [markdown]
# **→ Nhận xét:** Có thể thấy sự khác biệt theo mùa có tồn tại nhưng không đủ lớn để xác định một mùa cao điểm rõ rệt. **Mùa Thu** là mùa dẫn đầu với (27.1%) tổng số vụ, tiếp theo là **Mùa Hạ** (25.6%) và **Mùa Xuân** (24.0%). Ba mùa này cho thấy sự phân bố khá đồng đều. Ngược lại, **Mùa Đông** là mùa duy nhất có sự sụt giảm rõ ràng hơn, chỉ chiếm 23.3%, trở thành mùa có số vụ tai nạn thấp nhất. Tóm lại, mặc dù **Mùa Thu** là mùa có tần suất cao nhất, sự chênh lệch giữa các mùa chỉ mang tính tương đối trong một bức tranh khá cân bằng.

# %% [markdown]
# Sau khi xác định được bức tranh theo mùa, chúng ta cần đi sâu thêm vào hành vi thời gian bên trong mùa nhiều tai nạn nhất. ***Câu hỏi đặt ra là: trong mùa có tần suất tai nạn cao hơn, thì ngày nào trong tuần có xu hướng xảy ra tai nạn nhiều nhất?***

# %%
peak_season = 'Mùa thu'
peak_data = merged_data[merged_data['Season'] == peak_season]

day_mapping = {0:'Thứ 2', 1:'Thứ 3', 2:'Thứ 4', 3:'Thứ 5', 4:'Thứ 6', 5:'Thứ 7', 6:'Chủ nhật'}
peak_data['Day_name'] = peak_data['Day_of_week'].map(day_mapping)

# Biểu đồ cột số vụ tai nạn theo ngày trong tuần
plt.figure(figsize=(8,5))
sns.countplot(data=peak_data, x='Day_name', palette='Oranges', order=['Thứ 2','Thứ 3','Thứ 4','Thứ 5','Thứ 6','Thứ 7','Chủ nhật'])
plt.title(f"Số vụ tai nạn theo ngày trong tuần - {peak_season}")
plt.ylabel("Số vụ tai nạn")
plt.xlabel("Ngày trong tuần")
plt.show()
# Out:
# /tmp/ipython-input-3006072166.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   peak_data['Day_name'] = peak_data['Day_of_week'].map(day_mapping)
# /tmp/ipython-input-3006072166.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=peak_data, x='Day_name', palette='Oranges', order=['Thứ 2','Thứ 3','Thứ 4','Thứ 5','Thứ 6','Thứ 7','Chủ nhật'])

# %% [markdown]
# **→ Nhận xét:**
# + Nhìn vào biểu đồ trực quan các vụ tai nạn trong tuần vào Mùa Thu có thể thấy, số vụ duy trì sự "căng thẳng" ổn định từ **Thứ 2** đến **Thứ 5**, dao động quanh mốc 80.000 vụ. Thế nhưng, cao trào đích thực ập đến vào **Thứ 6** khi con số này vọt lên đỉnh cao nhất, xấp xỉ 90.000 vụ. Ngày này tập trung dồn nén cả áp lực di chuyển làm việc, vội vã về nhà, và cả các hoạt động giải trí trước cuối tuần.
# + Điều thú vị là, ngay sau đỉnh điểm **Thứ 6**, tần suất tai nạn giảm mạnh vào cuối tuần, với **Chủ Nhật** ghi nhận mức thấp nhất (khoảng 57.000 vụ). Sự sụt giảm rõ rệt này gợi ý một giả định mạnh mẽ: có vẻ như đa số mọi người có xu hướng hạn chế di chuyển đường dài hoặc cường độ cao vào cuối tuần, chọn ở nhà nghỉ ngơi hoặc giải trí tại chỗ. Chính sự thay đổi này trong thói quen sinh hoạt và mật độ giao thông đã giúp số vụ tai nạn giảm đáng kể, khiến **Chủ Nhật** trở thành ngày an toàn nhất trong tuần.

# %% [markdown]
# Sau khi nhận diện được Thứ 6 trong Mùa Thu là thời điểm có rủi ro tai nạn cao nhất – nơi mật độ giao thông, áp lực công việc và nhu cầu di chuyển đều đạt đến **“điểm sôi”**. Bước tiếp theo là đi sâu vào khung giờ.
# Bởi vì ngay trong một ngày nguy cơ cao, tai nạn không phân bố đều: sẽ có những thời điểm mà dòng xe đông đặc, sự vội vã tăng lên và mức độ nguy hiểm leo thang rõ rệt. Do đó, ***câu hỏi tiếp theo cần được giải quyết là: Trong ngày đỉnh điểm này, các vụ tai nạn tập trung chủ yếu vào khung giờ nào? Đó có phải giờ tan tầm hay là ban đêm – khi tầm nhìn giảm và rủi ro tăng?***

# %%
# Lọc dữ liệu: mùa thu + thứ 6
peak_data = merged_data[(merged_data['Season']=='Mùa thu') & (merged_data['Day_of_week']==4)]

time_order = ['Sáng sớm','Ban ngày','Chiều tối','Tối','Khuya']
time_counts = peak_data['Time_period'].value_counts().reindex(time_order)

plt.figure(figsize=(10,6))
sns.barplot(x=time_counts.index, y=time_counts.values, palette='Greens')

plt.title("Số vụ tai nạn theo khung giờ (Mùa thu, Thứ 6)")
plt.xlabel("Khung giờ")
plt.ylabel("Số vụ tai nạn")

# Tính tỉ lệ
total = time_counts.sum()
for i, v in enumerate(time_counts.values):
    plt.text(i, v + 350, f"{v} ({v/total:.1%})", ha='center', fontsize=10)

plt.show()
# Out:
# /tmp/ipython-input-685954085.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=time_counts.index, y=time_counts.values, palette='Greens')

# %% [markdown]
# **→ Nhận xét:** Khi nhìn sâu vào ngày nguy cơ cao nhất (Thứ 6 trong Mùa Thu), chúng ta có thể nhìn ra được câu chuyện của Giờ tan tầm. Áp lực và sự vội vã của mọi người đổ dồn vào khung **Chiều tối**, biến nó thành đỉnh điểm thảm họa, chiếm tỷ lệ 33.7% với 31.486 vụ tai nạn. Thậm chí, ngay cả **Ban ngày** (26.8%) và **Sáng sớm** (20.3%) cũng duy trì mức độ nguy hiểm cao, chứng minh rằng tai nạn chủ yếu gắn liền với cường độ giao thông đi lại và làm việc trong ngày. Ngược lại, khi nhịp sống chậm lại, số vụ cũng giảm dần; khung **Tối** chỉ còn 14.7%, và đặc biệt khung **Khuya** ghi nhận mức thấp nhất tuyệt đối, chỉ chiếm 4.5%. Điều này ngầm hiểu rằng, vào ngày nguy hiểm nhất, yếu tố chính thúc đẩy tai nạn có thể không phải là bóng tối hay các hoạt động về đêm, mà chính là sự tập trung quá tải của giao thông trong các khung giờ cao điểm ban ngày.

# %% [markdown]
# Sau khi đã hiểu được tai nạn xảy ra khi nào, bước tiếp theo là tìm hiểu tai nạn xảy ra ở đâu.
# Đầu tiên, cần xem xét mức độ phân bố tai nạn trên phạm vi toàn quốc để xác định vùng địa lý nào ghi nhận số vụ nhiều nhất — từ đó nhận diện các điểm nóng về mặt lãnh thổ. ***Câu hỏi đặt ra: Trên phạm vi toàn quốc, vùng địa lý nào ghi nhận số vụ tai nạn cao nhất? Có xuất hiện điểm nóng lãnh thổ hay không?***

# %%
# Tính số vụ tai nạn theo vùng địa lý
pf_counts = merged_data['Police_Force'].fillna('Missing').value_counts()
total = pf_counts.sum()

# Lấy Top 15
top_pf = pf_counts.head(15).reset_index()
top_pf.columns = ['Police_Force', 'Accident_Count']
top_pf['Percent'] = top_pf['Accident_Count'] / total

# Biểu đồ
plt.figure(figsize=(16,8))
sns.barplot(
    data=top_pf,
    x='Accident_Count',
    y='Police_Force',
    palette='Blues_r'
)

plt.title('Top 15 vùng có số vụ tai nạn cao nhất (Police_Force)')
plt.xlabel('Số vụ tai nạn')
plt.ylabel('Vùng (Police_Force)')

# Ghi số + tỉ lệ
for i, (cnt, pct) in enumerate(zip(top_pf['Accident_Count'], top_pf['Percent'])):
    plt.text(cnt + total*0.002, i, f"{cnt:,} ({pct:.1%})", va='center')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2720564976.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# **→ Nhận xét:** Phân tích số vụ tai nạn theo vùng địa lý cho thấy một bức tranh tổng thể về sự tập trung tai nạn không đồng đều trên toàn quốc, đồng thời khẳng định một quy luật chung: nơi nào có mật độ giao thông và kinh tế cao, nơi đó tai nạn nhiều. Cụ thể:
#   + Trên đỉnh cao của mọi vùng là **Metropolitan Police** (Vùng Cảnh sát Đô thị, London), một điểm nóng lãnh thổ cô độc, hoàn toàn thống trị với 305.911 vụ tai nạn, chiếm tới 14.9% tổng số vụ tai nạn trên toàn bộ Vương quốc Anh. Con số này gấp hơn 3.5 lần so với vùng đứng thứ hai là West Midlands (Tây Midlands, 86.469 vụ).
#   + Tuy nhiên, khi nhìn vào các vùng từ Top 2 trở xuống, sự phân bố tai nạn vẫn tuân theo một logic chặt chẽ: các vùng có số vụ cao tiếp theo đều là những trung tâm đô thị lớn (như **Tây Midlands**, **Tây Yorkshire**, **Đại Manchester**). Sự chênh lệch khổng lồ giữa London và phần còn lại cho thấy tầm quan trọng của thủ đô, nhưng sự tập trung tai nạn ở các vùng theo sau cũng khẳng định mật độ dân cư và kinh tế chính là động lực chính thúc đẩy tần suất tai nạn trên mọi khu vực.

# %% [markdown]
# Sau khi xác định vùng địa lý có số tai nạn cao nhất là London Metropolitan Police, chúng ta tiếp tục nhìn ở góc độ tính chất khu vực (Urban vs Rural) để xem tai nạn có tập trung ở đô thị hay nông thôn trên toàn quốc. ***Câu hỏi đặt ra: Khi thu nhỏ từ vùng địa lý vào môi trường cụ thể, tai nạn xảy ra nhiều hơn ở khu vực đô thị hay nông thôn?***

# %%
from matplotlib.ticker import MaxNLocator, FuncFormatter
# Chuẩn hóa dữ liệu
area_series = area_series.replace({'Unallocated': 'Khác'})

area_counts = area_series.value_counts().astype(int)
area_counts = area_counts.loc[['Urban', 'Rural']]
area_df = area_counts.reset_index()
area_df.columns = ['Area', 'Accident_Count']

total = area_df['Accident_Count'].sum()

plt.figure(figsize=(14,8))

area_order = ['Urban', 'Rural']
custom_palette = {
    'Urban': '#8B0000',
    'Rural': '#FF6B6B'
}

# Vẽ biểu đồ
ax = sns.barplot(
    data=area_df,
    x='Area',
    y='Accident_Count',
    palette=[custom_palette[a] for a in area_order]
)

plt.title("Phân bố tai nạn theo khu vực (Đô thị vs Nông thôn)", fontsize=18)
plt.xlabel("Khu vực", fontsize=15)
plt.ylabel("Số vụ tai nạn", fontsize=15)

plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, p: f"{int(x):,}"))

# Ghi số + tỉ lệ trên đầu cột
for i, row in area_df.iterrows():
    plt.text(
        i,
        row["Accident_Count"] + total * 0.005,
        f"{row['Accident_Count']:,} ({row['Accident_Count']/total:.1%})",
        ha='center',
        fontsize=13
    )

plt.ylim(0, area_df['Accident_Count'].max() * 1.15)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2157871263.py in <cell line: 0>()
#       1 from matplotlib.ticker import MaxNLocator, FuncFormatter
#       2 # Chuẩn hóa dữ liệu
# ----> 3 area_series = area_series.replace({'Unallocated': 'Khác'})
#       4
#       5 area_counts = area_series.value_counts().astype(int)
#
# NameError: name 'area_series' is not defined

# %% [markdown]
# **→ Nhận xét:** Từ biểu đồ chúng ta có thể thấy một sự chênh lệch rõ ràng và không thể phủ nhận giữa môi trường **Đô thị** và **Nông thôn**:
# + Khu vực **Đô thị (Urban)** hoàn toàn chiếm ưu thế về số vụ tai nạn, ghi nhận tới 1.284.345 vụ, chiếm tỷ lệ 62.401% trên tổng số. Con số này cao hơn gấp đôi so với Khu vực **Nông thôn (Rural)**, nơi ghi nhận 773.761 vụ, chiếm 37.594%.
# + Sự chênh lệch lớn này có thể là do tại **Đô thị**, tần suất tai nạn cao là hệ quả trực tiếp của Mật độ và Sự phức tạp của hệ thống đường sá, làm tăng khả năng xảy ra va chạm, dẫn đến tần suất cao tổng thể. Dữ liệu khẳng định Khu vực **Đô thị** là tâm điểm của các vụ tai nạn về mặt tần suất, đòi hỏi nguồn lực phải tập trung vào quản lý tắc nghẽn và giao thông phức hợp tại các thành phố.

# %% [markdown]
# Sau khi đã quan sát sự khác biệt về số vụ tai nạn giữa đô thị và nông thôn, ta có thể thấy môi trường xảy ra tai nạn có ảnh hưởng rõ rệt đến tần suất va chạm. Tuy nhiên, “đô thị hay nông thôn” vẫn là một góc nhìn khá rộng. Để hiểu rõ hơn nguyên nhân và bối cảnh, ta cần đi sâu vào đặc điểm hạ tầng giao thông. ***Câu hỏi đặt ra: Trong các loại đường khác nhau, đâu là loại đường ghi nhận số vụ tai nạn cao nhất?***

# %%
from matplotlib.ticker import MaxNLocator, FuncFormatter
# Đếm số lượng từng loại đường
road_series = merged_data['Road_Type']
road_counts = road_series.value_counts()
road_df = road_counts.reset_index()
road_df.columns = ['Road_Type', 'Accident_Count']

total = road_df['Accident_Count'].sum()

plt.figure(figsize=(18,8))

road_df = road_df.sort_values('Accident_Count', ascending=False)
colors = sns.color_palette("Set2", n_colors=len(road_df))

ax = sns.barplot(
    data=road_df,
    x='Road_Type',
    y='Accident_Count',
    palette=colors
)

plt.title("Số vụ tai nạn theo loại đường", fontsize=20)
plt.xlabel("Loại đường", fontsize=18)
plt.ylabel("Số vụ tai nạn", fontsize=18)

plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{int(x):,}"))

# Ghi số + tỉ lệ
for i, row in road_df.iterrows():
    plt.text(
        i,
        row["Accident_Count"] + total * 0.005,
        f"{row['Accident_Count']:,} ({row['Accident_Count']/total:.2%})",
        ha='center',
        fontsize=14
    )

plt.xticks(rotation=0, fontsize=16)
plt.yticks(fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# **→ Nhận xét:** Từ biểu đồ đã xác định rõ ràng nơi các sự cố giao thông xảy ra nhiều nhất, và câu trả lời nằm ở sự đơn giản của hạ tầng:
# + Loại đường **Đường đơn - Single Carriageway** (thường là đường hai chiều chỉ có một làn xe cho mỗi hướng) hoàn toàn áp đảo các loại đường khác về tần suất tai nạn, ghi nhận tới 1.505.053 vụ, chiếm tỷ lệ 73.12% trên tổng số. Các loại đường khác chỉ chiếm tỷ lệ nhỏ: **Dual Carriageway - Đường đôi** (thường có dải phân cách) đứng thứ hai với 17.07% (351.356 vụ), tiếp theo là **Roundabout - Vòng xuyến** với 6.85%.
# + Điều này có nghĩa là hơn 7/10 vụ tai nạn xảy ra trên loại đường này. Cho thấy nguyên nhân chính không hẳn là tốc độ cao, mà là mức độ tiếp xúc trực diện và điểm giao. Đường đơn thường xuyên có các nguy cơ như lấn làn khi vượt, va chạm trực diện, và nhiều giao lộ phức tạp hơn so với **Đường Đôi** hoặc **Đường Cao Tốc** có dải phân cách.

# %% [markdown]
# Xác định được loại đường rủi ro nhất giúp khoanh vùng yếu tố hạ tầng, nhưng loại đường chỉ là một phần của bức tranh. ***Điều gì xảy ra khi cùng một loại đường nhưng trong điều kiện thời tiết khác nhau? Đây là lúc ta cần xem xét yếu tố thời tiết để hiểu tai nạn có tăng lên trong mưa, sương mù hay thời tiết xấu hay không?***

# %%
from matplotlib.ticker import MaxNLocator, FuncFormatter
weather_series = merged_data['Weather_Conditions'].fillna('Unknown')
weather_counts = weather_series.value_counts()
weather_df = weather_counts.reset_index()
weather_df.columns = ['Weather', 'Accident_Count']
total = weather_df['Accident_Count'].sum()
weather_df = weather_df.sort_values('Accident_Count', ascending=False)

plt.figure(figsize=(16, 8))

sns.barplot(
    x='Accident_Count',
    y='Weather',
    data=weather_df,
    palette='Reds_r',
    order=weather_df['Weather']
)

plt.title("Số vụ tai nạn theo điều kiện thời tiết", fontsize=18, fontweight='bold')
plt.xlabel("Số vụ tai nạn", fontsize=14)
plt.ylabel("Điều kiện thời tiết", fontsize=14)
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))

for i, count in enumerate(weather_df['Accident_Count']):
    percent = (count / total * 100)
    plt.text(
        count + total*0.005,
        i,
        f"{count:,} ({percent:.1f}%)",
        va='center',
        fontsize=11
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# **→ Nhận xét:** Phân tích số vụ tai nạn theo điều kiện thời tiết cho thấy một nghịch lý đáng chú ý: phần lớn tai nạn xảy ra trong điều kiện thời tiết tốt, chứ không phải khi thời tiết xấu. Cụ thể, điều kiện **Fine no high winds (Thời tiết đẹp, không gió lớn)** hoàn toàn áp đảo, chiếm tới 1.698.133 vụ, tương đương 82.5% tổng số tai nạn. Ngược lại, các điều kiện thời tiết xấu như Mưa, Sương mù, hoặc Tuyết chỉ chiếm tỷ lệ nhỏ: **Raining no high winds (Mưa, không gió lớn)** là điều kiện thời tiết xấu phổ biến nhất, chỉ chiếm 11.6% (238.550 vụ). Bên cạnh đó, các điều kiện cực đoan khác (Tuyết, Sương mù, Mưa + Gió lớn) cộng lại chỉ chiếm dưới 5%. Do đó, có thể khẳng định rằng thời tiết xấu không phải là yếu tố chính gây ra phần lớn tai nạn.

# %% [markdown]
# Tương tự như với điều kiện thời tiết, ánh sáng cũng là một yếu tố quan trọng cần xem xét để hiểu nguyên nhân tai nạn. ***Câu hỏi đặt ra là: Điều kiện ánh sáng nào ghi nhận số vụ tai nạn cao nhất?***

# %%
from matplotlib.ticker import MaxNLocator, FuncFormatter
light_series = merged_data['Light_Conditions'].fillna('Unknown')
light_counts = light_series.value_counts()
light_df = light_counts.reset_index()
light_df.columns = ['Light', 'Accident_Count']

total_light = light_df['Accident_Count'].sum()
light_df = light_df.sort_values('Accident_Count', ascending=False)

plt.figure(figsize=(16, 8))

# Vẽ horizontal bar chart
sns.barplot(
    x='Accident_Count',
    y='Light',
    data=light_df,
    palette='Oranges_d',
    order=light_df['Light']
)

plt.title("Số vụ tai nạn theo điều kiện ánh sáng", fontsize=20)
plt.xlabel("Số vụ tai nạn", fontsize=16)
plt.ylabel("Điều kiện ánh sáng", fontsize=16)
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))

# Ghi số + phần trăm trên từng cột
for index, row in light_df.iterrows():
    plt.text(
        row['Accident_Count'] + total_light*0.005,
        index,
        f"{row['Accident_Count']:,} ({row['Accident_Count']/total_light:.2%})",
        va='center',
        fontsize=12
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# **→ Nhận xét:** Có thể xác nhận rõ ràng rằng tai nạn tập trung chủ yếu vào ban ngày chứ không phải ban đêm hay trong điều kiện ánh sáng kém. **Ánh sáng Ban ngày (Daylight)** hoàn toàn áp đảo về tần suất tai nạn ghi nhận tới 1.544.358 vụ chiếm tỷ lệ 75.03% trên tổng số. Điều này có nghĩa là 3/4 vụ tai nạn xảy ra khi tầm nhìn hoàn toàn rõ ràng. Ngược lại tai nạn xảy ra trong **bóng tối (Darkness)** chỉ chiếm một phần tư còn lại. Trong đó **Darkness - lights lit (Trời tối - Đèn đường bật sáng)** là điều kiện tối phổ biến nhất chiếm 18.55% (381.731 vụ) Các điều kiện tối khác (không đèn ánh sáng không rõ ràng) cộng lại chỉ chiếm dưới 6%. Dữ liệu khẳng định nguy cơ tai nạn chủ yếu gắn liền với mật độ và cường độ giao thông ban ngày. Rủi ro không đến từ bóng tối hay tầm nhìn kém, mà phát sinh từ chính sự phức tạp của giao thông và hành vi lái xe chủ quan trong điều kiện ánh sáng hoàn toàn rõ ràng.

# %% [markdown]
# Như vậy, thông qua phân tích đơn biến về thời điểm, địa lý, điều kiện thời tiết và ánh sáng, chúng ta đã nhận diện được các yếu tố môi trường chính ảnh hưởng đến số vụ tai nạn. Bước tiếp theo là đi sâu vào mức độ nghiêm trọng của tai nạn, để không chỉ biết tai nạn xảy ra ở đâu và khi nào, mà còn hiểu được tác động và hậu quả của từng vụ tai nạn. ***Câu hỏi đặt ra: Mức độ nghiêm trọng của các vụ tai nạn được ghi nhận như thế nào?***

# %%
from matplotlib.ticker import MaxNLocator, FuncFormatter
severity_series = merged_data['Accident_Severity'].fillna('Unknown')
severity_counts = severity_series.value_counts()
severity_df = severity_counts.reset_index()
severity_df.columns = ['Severity', 'Accident_Count']
total_severity = severity_df['Accident_Count'].sum()
severity_df = severity_df.sort_values('Accident_Count', ascending=False)

plt.figure(figsize=(14, 6))

# Vẽ cột dọc
sns.barplot(
    x='Severity',
    y='Accident_Count',
    data=severity_df,
    palette='Reds_d'
)

plt.title("Số vụ tai nạn theo mức độ nghiêm trọng", fontsize=18)
plt.xlabel("Mức độ nghiêm trọng", fontsize=14)
plt.ylabel("Số vụ tai nạn", fontsize=14)

# Ghi số + phần trăm trên cột
for index, row in severity_df.iterrows():
    plt.text(
        index,
        row['Accident_Count'] + total_severity*0.007,
        f"{row['Accident_Count']:,} ({row['Accident_Count']/total_severity:.2%})",
        ha='center',
        fontsize=12
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# **→ Nhận xét:** một bức tranh rõ ràng và trấn an: phần lớn các vụ tai nạn chỉ gây ra tổn thất nhẹ, trong khi tỷ lệ các vụ nghiêm trọng và tử vong chỉ là thiểu số. Cụ thể, **Tổn thất Nhẹ (Slight)** hoàn toàn áp đảo về tần suất, ghi nhận tới 1.765.472 vụ, chiếm tỷ lệ 85.78% trên tổng số, điều này ngầm giả định rằng đa số các sự cố là va chạm tốc độ thấp xảy ra trong các tình huống giao thông phức tạp (như kẹt xe ở Đô thị hoặc giờ tan tầm). Ngược lại, các vụ tai nạn nghiêm trọng và tử vong chỉ chiếm một tỷ lệ rất nhỏ: **Nghiêm trọng (Serious)** chiếm 12.89% (265.396 vụ), và **Tử vong (Fatal)** ghi nhận tỷ lệ thấp nhất tuyệt đối, chỉ 1.33% (27.328 vụ), tuy chiếm tỷ lệ nhỏ nhưng đại diện cho các vụ va chạm tốc độ cao hơn hoặc liên quan đến sự va đập mạnh.

# %% [markdown]
# ###**5.2.Phân tích đa biến (Multivariate Analysis)**

# %% [markdown]
# ###**5.3.Kiểm định giả thuyết (Hypothesis Testing)**

# %% [markdown]
# ##**6. Xây dựng mô hình (Model Building)**

# %% [markdown]
# ### **6.1. Chuẩn bị dữ liệu**

# %% [markdown]
# ### **6.2. Logistic Regression**

# %% [markdown]
# ### **6.3. Random Forest (RF Model)**

# %% [markdown]
# ##**7. Kết luận**
