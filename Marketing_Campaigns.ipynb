# %% [markdown]
# <a href="https://colab.research.google.com/github/mihhwiNick/DA_project/blob/hau/Marketing_Campaigns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tìm hiểu các tính năng và cách sử dụng sản phẩm SweetViz, AutoViz áp dụng trên tập dữ liệu Marketing Campaign

# %% [markdown]
# * Trong thời đại cạnh tranh khốc liệt hiện nay, việc hiểu rõ khách hàng trở thành yếu tố then chốt giúp doanh nghiệp duy trì lợi thế trên thị trường.
# Tuy nhiên, mỗi khách hàng đều có nhu cầu, hành vi và mối quan tâm khác nhau, khiến cho việc tiếp cận bằng một chiến lược marketing chung cho tất cả trở nên kém hiệu quả.
#
# * Để giải quyết vấn đề này, công ty đã triển khai dự án Customer Personality Analysis – phân tích tính cách và hành vi khách hàng.
# * Mục tiêu của dự án là xác định các nhóm khách hàng điển hình (customer segments), từ đó hiểu sâu hơn về đặc điểm, thói quen tiêu dùng và xu hướng mua hàng của từng nhóm.

# %% [markdown]
# ## Định nghĩa vấn đề

# %% [markdown]
# - Mô tả: Bộ dữ liệu Marketing Campaign mô tả thông tin nhân khẩu học, hành vi mua hàng, phản hồi chiến dịch và tương tác của khách hàng với công ty.
#
# - Dữ liệu vào:
#
#   - Thông tin cá nhân (People)
#     - ID: Mã nhận dạng duy nhất của khách hàng
#
#     - Year_Birth: Năm sinh của khách hàng
#
#     - Education: Trình độ học vấn của khách hàng
#
#     - Marital_Status: Tình trạng hôn nhân của khách hàng
#
#     - Income: Thu nhập hàng năm của hộ gia đình
#
#     - Kidhome: Số trẻ em trong hộ gia đình khách hàng
#
#     - Teenhome: Số thanh thiếu niên trong hộ gia đình khách hàng
#
#     - Dt_Customer: Ngày khách hàng đăng ký với công ty
#
#     - Recency: Số ngày kể từ lần mua hàng gần đây nhất của khách hàng
#
#     - Complain: 1 nếu khách hàng đã khiếu nại trong 2 năm qua, 0 nếu không
#
#   - Sản phẩm (Products)
#     - MntWines: Số tiền đã chi cho rượu vang trong 2 năm qua
#
#     - MntFruits: Số tiền đã chi cho trái cây trong 2 năm qua
#
#     - MntMeatProducts: Số tiền đã chi cho thịt trong 2 năm qua
#
#     - MntFishProducts: Số tiền đã chi cho cá trong 2 năm qua
#
#     - MntSweetProducts: Số tiền đã chi cho đồ ngọt trong 2 năm qua
#
#     - MntGoldProds: Số tiền đã chi cho sản phẩm vàng (trang sức, v.v.) trong 2 năm qua
#
#   - Khuyến mãi (Promotion)
#     - NumDealsPurchases: Số lần mua hàng được giảm giá
#
#     - AcceptedCmp1: 1 nếu khách hàng chấp nhận ưu đãi trong chiến dịch thứ nhất, 0 nếu không
#
#     - AcceptedCmp2: 1 nếu khách hàng chấp nhận ưu đãi trong chiến dịch thứ hai, 0 nếu không
#
#     - AcceptedCmp3: 1 nếu khách hàng chấp nhận ưu đãi trong chiến dịch thứ ba, 0 nếu không
#
#     - AcceptedCmp4: 1 nếu khách hàng chấp nhận ưu đãi trong chiến dịch thứ tư, 0 nếu không
#
#     - AcceptedCmp5: 1 nếu khách hàng chấp nhận ưu đãi trong chiến dịch thứ năm, 0 nếu không
#
#     - Response: 1 nếu khách hàng chấp nhận ưu đãi trong chiến dịch gần đây nhất, 0 nếu không
#
#   - Địa điểm (Place)
#     - NumWebPurchases: Số lần mua hàng qua trang web của công ty
#
#     - NumCatalogPurchases: Số lần mua hàng bằng catalog (ấn phẩm quảng cáo sản phẩm)
#
#     - NumStorePurchases: Số lần mua hàng trực tiếp tại cửa hàng
#
#     - NumWebVisitsMonth: Số lượt truy cập trang web của công ty trong tháng gần đây nhất
# - Dữ liệu ra: Sau khi phân tích bằng Sweetviz và AutoViz, kết quả đầu ra bao gồm:
#     - Sweetviz: File HTML (sweetviz_report.html).	Báo cáo tổng quan dữ liệu: thống kê mô tả, histogram, bar chart, phân bố biến, tỷ lệ dữ liệu thiếu, tương quan giữa các biến.
#     - AutoViz: Bộ biểu đồ trực quan (png).	Các biểu đồ phân tích đa biến như scatter plot, box plot, correlation heatmap, bar plot,… giúp phát hiện mối quan hệ giữa các biến.
# - Mục tiêu: biết được các tính năng và cách sử dụng sản phẩm SweetViz, AutoViz để phân tích khám phá dữ liệu
#     - Phân nhóm khách hàng:

# %% [markdown]
# ## Giới thiệu công cụ

# %% [markdown]
# ### Sweetviz

# %% [markdown]
# Sweetviz là một thư viện Python được thiết kế để phân tích dữ liệu khám phá (Exploratory Data Analysis – EDA) một cách tự động và trực quan.
# Công cụ này có khả năng:
#
# * Tự động tổng hợp, mô tả và so sánh các đặc trưng (features) trong tập dữ liệu.
#
# * Sinh ra báo cáo HTML trực quan, trong đó thể hiện:
#
# * Phân phối dữ liệu (Histogram cho biến số, Bar chart cho biến phân loại).
#
# * Thống kê cơ bản: trung bình, trung vị, min, max, độ lệch chuẩn.
#
# * Tỷ lệ dữ liệu thiếu (missing values) và tương quan giữa các biến.

# %% [markdown]
# ### AutoViz

# %% [markdown]
# AutoViz là thư viện Python mạnh mẽ dùng để tự động hóa quá trình trực quan hóa dữ liệu đa biến (Multivariate Analysis).
# Khác với Sweetviz chỉ tập trung mô tả, AutoViz giúp tìm mối quan hệ giữa các biến, phát hiện tương quan và xu hướng tiềm ẩn trong dữ liệu.
#
# Công cụ này:
#
# * Tự động xác định loại biến (số, phân loại, nhị phân, ngày tháng).
#
# * Tạo ra biểu đồ scatter plot, boxplot, heatmap, bar chart cho các cặp biến quan trọng.
#
# * Tự động chọn biến “phụ thuộc” (depVar) để xem mối quan hệ với các biến còn lại.
#
# * Giúp người dùng phát hiện các cụm khách hàng, hành vi chi tiêu, và mối tương quan trong dữ liệu.
#
# Ưu điểm:
#
# * Phân tích đa biến (bivariate/multivariate) tự động.
#
# * Trực quan hóa mối quan hệ giữa các thuộc tính.
#
# * Hỗ trợ nhiều loại dữ liệu, kể cả dữ liệu lớn.

# %% [markdown]
# ## Chuẩn bị môi trường

# %%
# !pip install -q sweetviz==2.3.1 numpy==1.26.4 pandas matplotlib

# !sed -i '71s/^/#/' /usr/local/lib/python3.12/dist-packages/sweetviz/graph_numeric.py
# !sed -i '74s/^/#/' /usr/local/lib/python3.12/dist-packages/sweetviz/graph_numeric.py

# !sed -i 's/^#*\s*self\.hist_specs/self.hist_specs/' /usr/local/lib/python3.12/dist-packages/sweetviz/graph_numeric.py

# !head -n 80 /usr/local/lib/python3.12/dist-packages/sweetviz/graph_numeric.py | tail -n 15
# !sed -i '72,73c\        self.hist_specs = axs.hist(plot_data, weights=normalizing_weights, bins=self.num_bins, \\\n                           rwidth=(100.0 - gap_percent) / 100.0)' /usr/local/lib/python3.12/dist-packages/sweetviz/graph_numeric.py

# %%
# !pip install -q autoviz

# %% [markdown]
# ## Khai báo thư viện

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter
import numpy as np
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class
import sweetviz as sv
from IPython.display import display, HTML
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load dataset

# %%
# Set the path to the file you'd like to load
file_path = "marketing_campaign.csv"

# Load the latest version
df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "imakash3011/customer-personality-analysis",
  file_path,
  pandas_kwargs={
      # Use tab as a separator
      'sep': '\t',
      'engine': 'python'
  }
)
# hiển thị 5 dòng đầu
df.head(5)

# %% [markdown]
# ## Thông tin tổng quát về dữ liệu

# %% [markdown]
# ### Kiểm tra kiểu dữ liệu và tính đầy đủ của dữ liệu

# %%
df.info()

# %% [markdown]
# Nhận xét:
# * Tổng số dòng dữ liệu là 2240 dòng
# * Kiểu dữ liệu gồm: số nguyên(int), số thực(float), chuỗi(object)
# * Cột Income bị thiếu dữ liệu

# %% [markdown]
# ### Thống kê mô tả

# %%
df.describe()

# %% [markdown]
# Nhận xét:
# - Count(số lượng)
#   - Vì tổng số lượng của Income là 2216, trong khi các biến còn lại là 2240, nên cần tiến hành xử lí dữ liệu.
# - mean(trung bình)
#   - Vì trung bình của Year_Birth là 1968, nên độ tuổi trung bình là 53 tuổi(tính đến năm 2021)
#   - Trung bình của thu nhập là 52247
#   - Vì trung bình của MntWines, MntMeatProducts cao hơn so với những thứ còn lại, nên chứng tỏ rượu vang và thịt được mua nhiều nhất
# - std(độ lệch chuẩn)
#     - Vì độ lệch chuẩn của Income,Recency  là rất cao, nên chứng tỏ biến Income,Recency  có độ phân tán cao
# - min, max:
#   - Có sự chênh lệch giữa min và max của các biến Income, Mnt(*), cho thấy dữ liệu có sự chênh lệch đáng kể

# %% [markdown]
# ## Làm sạch dữ liệu

# %% [markdown]
# Một số cột không cần thiết cho việc phân tích nhóm khách hàng và nên được loại bỏ để giảm nhiễu:
#
# * ID: Mã định danh duy nhất của khách hàng. Nó không mang ý nghĩa phân tích và chỉ dùng để nhận dạng khách hàng.
#
# * Dt_Customer: Ngày khách hàng đăng ký. Mặc dù có thể dùng để tính tuổi đời khách hàng, nhưng Recency (thời gian mua hàng gần nhất) thường mang ý nghĩa thực tế hơn cho việc phân tích hành vi.

# %%
cols_to_use = ['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome',
 'Recency', 'Complain',
 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
 'NumDealsPurchases', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'Response',
 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']

# %% [markdown]
# ### Xử lí dữ liệu trùng lập

# %%
# Kiểm tra dữ liệu trùng lặp
duplicate_rows = df[cols_to_use].duplicated()
print('Số hàng trùng lặp:', duplicate_rows.sum())

# %%
# xóa dữ liệu trùng lặp
marketing_data= df[cols_to_use].drop_duplicates()

# Kiểm tra số hàng sau khi xóa
print('Số hàng sau khi xóa:', len(marketing_data))

# %% [markdown]
# ### Thay thế dữ liệu

# %%
#Kiểm tra các giá trị trong cột Kidhome, Teenhome:
print('Kidhome:',marketing_data['Kidhome'].unique())
print('Teenhome:',marketing_data['Teenhome'].unique())

# %%
# Thay thế dữ liệu của Kidhome, Teenhome bằng 'has teen','has no teen'
marketing_data['Teenhome'] = marketing_data['Teenhome'].replace([0, 1, 2], ['has no teen', 'has teen', 'has teen'])
marketing_data['Kidhome'] = marketing_data['Kidhome'].replace([0, 1, 2], ['has no kid', 'has kid', 'has kid'])

# Kiểm tra sau khi thay đổi:
print('Kidhome:',marketing_data['Kidhome'].unique())
print('Teenhome:',marketing_data['Teenhome'].unique())

# %% [markdown]
# Nhận xét:
#
#
# *   Vì Kidhome, Teenhome chứa số lượng trẻ em trong gia đình, nên ta tiến hành thay thế dữ liệu sang 'has no kid' với các giá trị bằng 0, 'has kid' với giá trị lớn hơn 0

# %% [markdown]
# ### Xử lí dữ liệu bị thiếu

# %% [markdown]
# #### Xử lí dữ liệu bị thiếu

# %%
# Kiểm tra số lượng dữ liệu bị thiếu
marketing_data.isnull().sum()

# %%
# Xóa dữ liệu bị thiếu
marketing_data.dropna(subset=['Income'], inplace=True)
print("\n kiểm tra lại:")
print(marketing_data.isnull().sum())

# %% [markdown]
# ### Tạo thêm cột mới

# %% [markdown]
# * Để chuẩn bị dữ liệu cho việc phân tích chuyên sâu hơn và xây dựng các mô hình phân khúc khách hàng tiềm năng, chúng ta cần tạo ra các biến tổng hợp quan trọng. Việc này sẽ giúp tóm tắt hành vi chi tiêu và tình trạng gia đình của khách hàng, từ đó tạo ra những hiểu biết sâu sắc hơn về khách hàng.
#
# * Chúng ta sẽ thực hiện hai bước sau:
#     1. Tính tổng chi tiêu toàn bộ (Total_Spent): Nhằm đánh giá tổng quan khả năng chi tiêu của mỗi khách hàng trên tất cả các danh mục sản phẩm.
#
#     2. Phân loại tình trạng con cái (Family_Type): Nhằm đơn giản hóa cấu trúc gia đình, phân loại khách hàng thành hai nhóm rõ ràng là 'Có con' và 'Không có con' để xem yếu tố con cái ảnh hưởng như thế nào đến hành vi mua sắm của họ.

# %%
# Tổng số tiền chi tiêu
marketing_data['Total_Spent'] = marketing_data[['MntWines','MntFruits','MntMeatProducts',
                        'MntFishProducts','MntSweetProducts','MntGoldProds']].sum(axis=1)

# Kiểm tra xem có con hay không
def family_type(row):
    if row['Kidhome'] == 'has no kid' and row['Teenhome'] == 'has no teen':
        return 'No Children'
    else:
        return 'Has Children'

marketing_data['Family_Type'] = marketing_data.apply(family_type, axis=1)

# Kiểm tra dữ liệu
marketing_data.head()

# %% [markdown]
# ## Phân tích khám phá dữ liệu

# %% [markdown]
# ### SweetViz

# %%
sweetviz_don_bien = sv.analyze(marketing_data)
sweetviz_don_bien.show_html('sweetviz_don_bien.html', open_browser=False)
display(HTML('sweetviz_don_bien.html'))

# %% [markdown]
# #### Phân tích thu nhập (Income)

# %% [markdown]
# Biểu đồ này có thể trả lời câu hỏi sau:
# * Thu nhập của khách hàng có mối quan hệ như thế nào với hành vi chi tiêu và hình thức mua sắm?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nhận xét:
#
#
# *   Phần lớn khách hàng có thu nhập từ 0 - 10000, tuy nhiên vẫn có 1 số ít có mức lương trên 150000(giá trị ngoại lai - outliers)
# * Sự tương quan
#   * Tương quan cao với Total_Spent, MntMeatProducts, MntWines. Chứng tỏ người có thu nhập cao sẽ mua sắm nhiều hơn, đặc biệt là sản phẩm về MntMeatProducts, MntWines.
#   * Tương quan cao với NumCatalogPurchases cho biết người thu nhập cao sẽ thích mua sắm qua catalog hơn.

# %% [markdown]
# #### Phân tích trình độ học vấn(Education)

# %% [markdown]
# Biểu đồ này sẽ trả lời câu hỏi:
# * Trình độ học vấn của khách hàng có ảnh hưởng như thế nào đến thu nhập và mức chi tiêu?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nhận xét:
# * Biểu đồ cho thấy Graduation là trình độ học vấn phổ biến nhất, chiếm gần 50% tệp khách hàng. Các trình độ sau đại học như PhD và Master cũng chiếm tỷ lệ đáng kể, cho thấy tệp khách hàng có trình độ học vấn cao.
# * Các cấp độ thấp hơn như 2n Cycle và Basic chiếm tỷ lệ nhỏ.
# * Sự tương quan:
#   * Tương quan nhẹ với MntWines, Income cho biết người học vấn cao sẽ có mức lương cao và dành nhiều chi phí cho rượu vang hơn.

# %% [markdown]
# #### Phân tích tình trạng hôn nhân (Marital_Status)

# %% [markdown]
# Biểu đồ này sẽ trả lời câu hỏi sau:
# * Trình độ học vấn ảnh hưởng như thế nào đến thu nhập và chi tiêu của khách hàng?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nhận xét:
# *  Biểu đồ cột cho thấy khách hàng chủ yếu thuộc hai nhóm Married (≈38%) và Together (≈25%), chiếm hơn 60% tổng số, cho thấy sự ổn định trong hôn nhân và gia đình là đặc điểm chung của tệp khách hàng.
# * Sự tương quan:
#   * Tương quan nhẹ với MntFishProducts, MntGoldProds, cho biết người ổn định trong hôn nhân có xu hướng mua những thứ này hơn.

# %% [markdown]
# #### Phân tích mua hàng giảm giá(NumDealsPurchases)

# %% [markdown]
# Biểu đồ này sẽ trả lời câu hỏi:
# * Khách hàng có xu hướng mua hàng giảm giá như thế nào và yếu tố nào ảnh hưởng đến hành vi này?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nhận xét:
# * Biểu đồ cho thấy phân bố NumDealsPurchases bị lệch phải rất mạnh. Hơn 40% khách hàng có giá trị bằng 0 (hầu như không mua hàng giảm giá), trong khi chỉ một số ít mua hàng giảm giá nhiều lần.
# * Phần lớn khách hàng (trên 90%) mua hàng giảm giá từ 0 đến 4 lần. Điều này cho thấy công ty có một nhóm khách hàng không quan tâm nhiều đến giảm giá, và một nhóm nhỏ sử dụng chúng ở mức độ vừa phải.
#
# * Sự tương quan:
#   * Tương quan âm nhẹ với Income (-0.08) và Total_Spend (-0.51). Điều này cho thấy khách hàng có thu nhập cao và chi tiêu nhiều ít khi mua hàng giảm giá.
#
#   * Tương quan dương với Kênh Web: Có tương quan dương với NumWebVisitsMonth (0.35) và NumWebPurchases (0.23). Điều này cho thấy những người thường xuyên truy cập trang web và mua sắm trực tuyến có xu hướng sử dụng mã giảm giá nhiều hơn.

# %% [markdown]
# #### Tổng kết Sweetviz

# %% [markdown]
# Sweetviz giúp nhận diện nhanh các đặc điểm cơ bản của tập dữ liệu:
#
# * Thu nhập (Income) lệch phải → nên chuẩn hóa.
#
# * Tình trạng hôn nhân và học vấn cho thấy xu hướng chi tiêu khác nhau.
#
# * Các biến như Recency, Complain phản ánh mức độ tương tác của khách hàng

# %% [markdown]
# ### AutoViz

# %%
# !pip install matplotlib --upgrade
# %matplotlib inline
AV = AutoViz_Class()
AV.AutoViz(    filename='',
    dfte=marketing_data,
    verbose=1,
    chart_format='png'
)
plt.close('all')

# %% [markdown]
# #### Phân tích bằng biểu đồ Heatmap

# %% [markdown]
# Biểu đồ này sẽ trả lời câu hỏi:
# * Liệu thu nhập của khách hàng (Income) có ảnh hưởng đến mức chi tiêu của họ không?
# * Khách hàng có xu hướng chi tiêu tập trung vào một sản phẩm, hay mua nhiều loại sản phẩm khác nhau cùng lúc?

# %% [markdown]
# ![sweetviz1.png](data:image/png;base64,...)

# %% [markdown]
# Nhận xét:
# * Income (thu nhập) có tương quan dương rõ với Total_spent,MntWines, MntGoldProds, MntMeatProducts (0.5 - 0.6) → thu nhập càng cao, chi tiêu càng lớn cho các mặt hàng giá trị cao.
# * Các biến MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds' có tương quan dương từ 0.3 trở lên, chứng tỏ tệp khách hàng có xu hướng mua các sản phẩm này chung với nhau, chứ không phải tập trung vào 1 sản phẩm nhất định.

# %% [markdown]
# #### Phân tích giữa Income và Total_Spend

# %% [markdown]
# Biểu đồ này trả lời câu hỏi:
# * Liệu thu nhập (Income) có ảnh hưởng trực tiếp đến tổng chi tiêu (Total_Spent) của khách hàng hay không?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nhận xét:
# * Nhìn chung, thu nhập trung bình có xu hướng giảm dần khi tổng chi tiêu giảm.
#
# * Hai khách hàng chi tiêu cao nhất (ID 1717 và 1608) có thu nhập vượt trội, lần lượt trên 150.000 — cao hơn hẳn phần còn lại (đa phần chỉ quanh mức 100.000).
#
# * Tuy nhiên, sau nhóm top đầu, mức thu nhập giữa các khách hàng chi tiêu cao còn lại khá đồng đều, không còn chênh lệch lớn.
#
# * Điều này cho thấy thu nhập cao là yếu tố thuận lợi để chi tiêu lớn, nhưng không phải yếu tố duy nhất — vẫn có khách hàng thu nhập trung bình nhưng chi tiêu mạnh, có thể thuộc nhóm khách hàng trung thành hoặc chi tiêu theo sở thích.

# %% [markdown]
# #### Phân tích giữa Income và NumDealsPurchases

# %% [markdown]
# Biểu đồ này trả lời câu hỏi:
# * Mối quan hệ giữa thu nhập của khách hàng (Income) và số lần mua hàng có giảm giá (NumDealsPurchases) là gì?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nhận xét:
# * Biểu đồ cho thấy những người có thu nhập trung bình cao nhất(khoảng 80000) lại là những người có số lần mua hàng giảm giá bằng 0. Khi số lần mua hàng giảm giá tăng lên, thu nhập trung bình của nhóm khách hàng đó lại có xu hướng giảm dần.
#
# * Khách hàng thu nhập cao: Những người có thu nhập cao có vẻ như ít quan tâm đến các chương trình khuyến mãi hoặc giảm giá. Họ sẵn sàng mua sản phẩm với giá gốc, điều này có thể phản ánh lòng trung thành với thương hiệu hoặc đơn giản là họ không nhạy cảm với giá cả.
#
# * Khách hàng thu nhập thấp: Ngược lại, những người có thu nhập thấp hơn dường như có xu hướng sử dụng các ưu đãi giảm giá thường xuyên hơn để tiết kiệm chi phí. Điều này cho thấy họ là nhóm khách hàng nhạy cảm với giá cả.

# %% [markdown]
# #### Phân tích giữa Income và NumWebPurchases/NumStorePurchases/CatalogPurchases

# %% [markdown]
# Các biểu đồ trả lời câu hỏi:
# * Khách hàng có thu nhập cao thường mua hàng qua kênh nào nhiều nhất — website, cửa hàng, hay catalogue?
# * Liệu thu nhập có ảnh hưởng đến sở thích kênh mua hàng hay không?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nhận xét:
# * Nhóm khách hàng có thu nhập cao (trên 100.000) thường có số lần mua qua Catalog hoặc Website nhiều hơn, cho thấy họ ưa chuộng sự tiện lợi và quen thuộc với thương hiệu.
#
# * Ngược lại, nhóm thu nhập trung bình - thấp (dưới 100.000) có xu hướng mua hàng trực tiếp tại cửa hàng, có thể vì họ muốn xem sản phẩm thực tế hoặc ít sử dụng các kênh mua sắm trực tuyến.

# %% [markdown]
# #### Tổng kết AutoViz

# %% [markdown]
# * AutoViz cho phép trực quan hóa mối quan hệ giữa thu nhập, chi
# tiêu, và hành vi mua hàng.
# * Kết quả:
#     * Kết quả chỉ ra rằng người có lương cao sẽ dành nhiều chi phí hơn cho việc mua sắm, mua hàng khi cần mà không đợi đến lúc khuyến mãi, thích mua hàng trực tuyến hơn đi đến cửa hàng
#     * Ngược lại, nhóm người có mức lương thấp sẽ tiết kiệm hơn trong việc mua sắm, thích đến cửa hàng để mua, thích mua hàng được giảm giá

# %% [markdown]
# # Kết luận

# %% [markdown]
# Qua quá trình phân tích dữ liệu bằng Sweetviz và AutoViz, có thể rút ra một số đặc điểm nổi bật giúp định hình các nhóm khách hàng (customer segments) như sau:
#
# 1. Nhóm thu nhập cao (Income > 100.000):
#
# Thường chi tiêu mạnh cho các sản phẩm có giá trị cao như rượu vang (MntWines), thịt (MntMeatProducts) và vàng (MntGoldProds).
#
# Ưa chuộng các kênh mua hàng hiện đại như Catalog và Website, ít quan tâm đến khuyến mãi hoặc giảm giá.
# → Đây là nhóm khách hàng cao cấp - trung thành, có thể tập trung các chiến dịch quảng bá sản phẩm cao cấp.
#
# 2. Nhóm thu nhập trung bình (≈ 40.000 – 100.000):
#
# Có hành vi chi tiêu ổn định, chủ yếu mua hàng trực tiếp tại cửa hàng (Store).
#
# Có thể sử dụng một vài ưu đãi giảm giá, nhưng không thường xuyên.
# → Đây là nhóm khách hàng truyền thống, nên ưu tiên chương trình khuyến mãi hoặc thẻ thành viên để tăng tần suất mua hàng.
#
# 3.  Nhóm thu nhập thấp (< 40.000):
#
# Nhạy cảm với giá, thường mua khi có giảm giá hoặc ưu đãi trực tuyến.
#
# Chi tiêu tổng thể thấp, ít mua các sản phẩm cao cấp.
# → Là nhóm khách hàng nhạy cảm về giá, phù hợp với các chiến dịch giảm giá ngắn hạn.
#
# 4.  Đặc điểm chung về nhân khẩu học:
#
# Đa số khách hàng thuộc nhóm Married hoặc Together, thể hiện sự ổn định trong gia đình.
#
# Phần lớn có trình độ Graduation trở lên, cho thấy tệp khách hàng có mức học vấn và thu nhập tương đối cao.
