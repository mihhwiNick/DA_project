# %% [markdown]
# <a href="https://colab.research.google.com/github/mihhwiNick/DA_project/blob/hoang/Red_Wine_Quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Dự đoán về chất lượng rượu vang**

# %% [markdown]
# Phân tích và dự đoán chất lượng của rượu dựa vào bộ dữ liệu

# %% [markdown]
# # Giải thích biến dữ liệu

# %% [markdown]
# Giải thích biến:
# *  **Fixed acidity (Độ axit cố định)**: Là các loại axit không bay hơi (không dễ bay hơi). Độ axit này được xác định bởi tổng lượng axit có trong mẫu. Axit cố định gồm các axit hữu cơ có độ bay hơi thấp như axit malic, lactic, tartaric hoặc citric — những thành phần đặc trưng cho mẫu rượu.
# *   **Volatile acidity (Độ axit bay hơi)**: Là lượng axit axetic có trong rượu; nếu quá cao sẽ gây mùi vị khó chịu như giấm. Axit bay hơi gồm các axit hữu cơ mạch ngắn có thể tách ra khỏi mẫu bằng quá trình chưng cất như axit fomic, axit axetic, axit propionic và axit butyric.
# *   **Citric acid (Axit citric)**: Có trong rượu với lượng nhỏ, giúp tạo vị “tươi mát” và hương vị dễ chịu. Đây là một axit hữu cơ yếu, không màu, có tự nhiên trong các loại trái cây họ cam quýt. Trong sinh hóa, nó là chất trung gian trong chu trình axit citric (chu trình Krebs) diễn ra trong quá trình trao đổi chất của sinh vật hiếu khí.
# *   **Residual sugar (Lượng đường dư)**: Là lượng đường còn lại sau khi quá trình lên men dừng lại. Thông thường rượu hiếm khi có dưới 1 g/l đường. Lượng đường dư ảnh hưởng đến độ ngọt của rượu và được đo bằng gam đường trên mỗi lít (g/l). Ở EU, lượng đường dư còn được quy định để gắn nhãn phân loại rượu.
# *   **Chlorides (Lượng muối)**: Là lượng ion chloride (Cl⁻) có trong rượu. Rượu đỏ thường có lượng chloride cao hơn do quá trình chiết xuất từ vỏ nho trong quá trình lên men. Nước ép nho đỏ không nên vượt quá 356 mg/L ion chloride, để rượu thành phẩm không vượt quá mức pháp lý tối đa 606 mg/L.
# *   **Free sulfur dioxide (SO₂ tự do)**: Là dạng SO₂ tồn tại tự do trong dung dịch (dưới dạng khí hòa tan hoặc ion bisulfite). SO₂ tự do có khả năng phản ứng, mang tính kháng khuẩn và chống oxy hóa. Ngược lại, SO₂ liên kết là phần đã phản ứng với các phân tử khác trong rượu. Tổng hai phần này tạo nên tổng lượng SO₂.
# *   **Total sulfur dioxide (Tổng SO₂)**: Là tổng lượng SO₂ tự do và SO₂ liên kết. Ở nồng độ thấp, SO₂ hầu như không được cảm nhận trong rượu, nhưng nếu cao có thể gây mùi khó chịu. Đây là chỉ tiêu quan trọng để kiểm soát chất lượng và độ bền của rượu.
# *   **Density (Mật độ)**: Mật độ của rượu gần bằng nước, phụ thuộc vào hàm lượng cồn và đường. Dụng cụ đo mật độ là hydrometer — một ống thủy tinh có đầu nặng, dùng để đo tỉ trọng của rượu so với nước (gọi là “specific gravity”).
# *   **pH**: Cho biết độ axit hoặc độ kiềm của rượu trên thang 0–14 (0: rất axit, 14: rất kiềm). Phần lớn rượu có pH từ 3 đến 4. Rượu có pH cao (>3,65) dễ bị hư hỏng do vi sinh vật. Vì vậy, người làm rượu thường bổ sung SO₂ (dưới dạng kali metabisulfite) để ổn định rượu trong quá trình ủ và bảo quản.
# *   **Sulphates (Sunphat)**: Là phụ gia có thể góp phần hình thành khí SO₂, giúp diệt khuẩn và bảo quản rượu. Sulphate tự nhiên có sẵn ở mức thấp trong tất cả các loại rượu do quá trình lên men, nhưng cũng thường được bổ sung thêm. Một số người nhạy cảm với sulphite có thể bị đau đầu hoặc nghẹt mũi sau khi uống rượu có nồng độ cao.
# *   **Alcohol (Nồng độ cồn)**: Là tỷ lệ phần trăm (%) cồn ethanol trong rượu — yếu tố chính ảnh hưởng đến hương vị, độ nặng và cảm giác khi uống.
# *   **Quality (Chất lượng)**: Là biến đầu ra (output variable), được đánh giá dựa trên dữ liệu cảm quan (taste test) với thang điểm từ 3 đến 8.

# %% [markdown]
# # Import Thư Viện

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import scipy.stats as st
from termcolor import colored

# %% [markdown]
# # Tải Dữ liệu

# %%
wine = pd.read_csv("winequality-red.csv")
df = wine.copy()
df.head(n = 10).style.background_gradient(cmap = "Purples_r")
# Out:
# <style type="text/css">
# #T_c4d7b_row0_col0, #T_c4d7b_row4_col0, #T_c4d7b_row5_col0 {
#   background-color: #430780;
#   color: #f1f1f1;
# }
# #T_c4d7b_row0_col1, #T_c4d7b_row4_col1 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_c4d7b_row0_col2, #T_c4d7b_row0_col10, #T_c4d7b_row0_col11, #T_c4d7b_row1_col2, #T_c4d7b_row1_col11, #T_c4d7b_row2_col11, #T_c4d7b_row3_col1, #T_c4d7b_row3_col8, #T_c4d7b_row4_col2, #T_c4d7b_row4_col10, #T_c4d7b_row4_col11, #T_c4d7b_row5_col2, #T_c4d7b_row5_col10, #T_c4d7b_row5_col11, #T_c4d7b_row6_col9, #T_c4d7b_row6_col10, #T_c4d7b_row6_col11, #T_c4d7b_row7_col0, #T_c4d7b_row7_col2, #T_c4d7b_row7_col3, #T_c4d7b_row7_col4, #T_c4d7b_row7_col7, #T_c4d7b_row8_col5, #T_c4d7b_row8_col6, #T_c4d7b_row9_col11 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_c4d7b_row0_col3, #T_c4d7b_row3_col3, #T_c4d7b_row4_col3 {
#   background-color: #572c92;
#   color: #f1f1f1;
# }
# #T_c4d7b_row0_col4, #T_c4d7b_row4_col4 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_c4d7b_row0_col5, #T_c4d7b_row1_col0, #T_c4d7b_row2_col0, #T_c4d7b_row4_col5, #T_c4d7b_row8_col0 {
#   background-color: #54278f;
#   color: #f1f1f1;
# }
# #T_c4d7b_row0_col6, #T_c4d7b_row4_col6 {
#   background-color: #5f3c99;
#   color: #f1f1f1;
# }
# #T_c4d7b_row0_col7, #T_c4d7b_row4_col7, #T_c4d7b_row5_col7, #T_c4d7b_row9_col7 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_c4d7b_row0_col8, #T_c4d7b_row1_col1, #T_c4d7b_row1_col4, #T_c4d7b_row1_col5, #T_c4d7b_row3_col0, #T_c4d7b_row3_col2, #T_c4d7b_row3_col7, #T_c4d7b_row4_col8, #T_c4d7b_row5_col8, #T_c4d7b_row7_col11, #T_c4d7b_row8_col11, #T_c4d7b_row9_col3, #T_c4d7b_row9_col6, #T_c4d7b_row9_col9, #T_c4d7b_row9_col10 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_c4d7b_row0_col9, #T_c4d7b_row4_col9, #T_c4d7b_row5_col9 {
#   background-color: #7261ab;
#   color: #f1f1f1;
# }
# #T_c4d7b_row1_col3, #T_c4d7b_row2_col8 {
#   background-color: #705eaa;
#   color: #f1f1f1;
# }
# #T_c4d7b_row1_col6 {
#   background-color: #b2b2d5;
#   color: #000000;
# }
# #T_c4d7b_row1_col7, #T_c4d7b_row1_col9, #T_c4d7b_row8_col7 {
#   background-color: #c1c2df;
#   color: #000000;
# }
# #T_c4d7b_row1_col8 {
#   background-color: #52238d;
#   color: #f1f1f1;
# }
# #T_c4d7b_row1_col10, #T_c4d7b_row2_col10, #T_c4d7b_row3_col10, #T_c4d7b_row9_col1 {
#   background-color: #7e79b8;
#   color: #f1f1f1;
# }
# #T_c4d7b_row2_col1 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_c4d7b_row2_col2 {
#   background-color: #4b1687;
#   color: #f1f1f1;
# }
# #T_c4d7b_row2_col3 {
#   background-color: #65489f;
#   color: #f1f1f1;
# }
# #T_c4d7b_row2_col4 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_c4d7b_row2_col5, #T_c4d7b_row6_col5, #T_c4d7b_row7_col5 {
#   background-color: #807dba;
#   color: #f1f1f1;
# }
# #T_c4d7b_row2_col6 {
#   background-color: #8d89c0;
#   color: #f1f1f1;
# }
# #T_c4d7b_row2_col7 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_c4d7b_row2_col9 {
#   background-color: #adabd2;
#   color: #000000;
# }
# #T_c4d7b_row3_col4, #T_c4d7b_row5_col4 {
#   background-color: #7363ad;
#   color: #f1f1f1;
# }
# #T_c4d7b_row3_col5, #T_c4d7b_row3_col6, #T_c4d7b_row3_col11, #T_c4d7b_row9_col5 {
#   background-color: #9e9bc8;
#   color: #f1f1f1;
# }
# #T_c4d7b_row3_col9 {
#   background-color: #7c75b6;
#   color: #f1f1f1;
# }
# #T_c4d7b_row5_col1 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_c4d7b_row5_col3, #T_c4d7b_row6_col4 {
#   background-color: #53268f;
#   color: #f1f1f1;
# }
# #T_c4d7b_row5_col5 {
#   background-color: #6a51a3;
#   color: #f1f1f1;
# }
# #T_c4d7b_row5_col6 {
#   background-color: #6c55a5;
#   color: #f1f1f1;
# }
# #T_c4d7b_row6_col0 {
#   background-color: #593093;
#   color: #f1f1f1;
# }
# #T_c4d7b_row6_col1 {
#   background-color: #a6a3cd;
#   color: #f1f1f1;
# }
# #T_c4d7b_row6_col2 {
#   background-color: #51218c;
#   color: #f1f1f1;
# }
# #T_c4d7b_row6_col3 {
#   background-color: #4c1888;
#   color: #f1f1f1;
# }
# #T_c4d7b_row6_col6 {
#   background-color: #9b97c6;
#   color: #f1f1f1;
# }
# #T_c4d7b_row6_col7 {
#   background-color: #a5a2cd;
#   color: #f1f1f1;
# }
# #T_c4d7b_row6_col8 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_c4d7b_row7_col1 {
#   background-color: #babadb;
#   color: #000000;
# }
# #T_c4d7b_row7_col6, #T_c4d7b_row8_col2 {
#   background-color: #450b82;
#   color: #f1f1f1;
# }
# #T_c4d7b_row7_col8 {
#   background-color: #c4c5e0;
#   color: #000000;
# }
# #T_c4d7b_row7_col9 {
#   background-color: #440981;
#   color: #f1f1f1;
# }
# #T_c4d7b_row7_col10 {
#   background-color: #a9a7cf;
#   color: #f1f1f1;
# }
# #T_c4d7b_row8_col1 {
#   background-color: #9e9ac8;
#   color: #f1f1f1;
# }
# #T_c4d7b_row8_col3 {
#   background-color: #5a3395;
#   color: #f1f1f1;
# }
# #T_c4d7b_row8_col4 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_c4d7b_row8_col8 {
#   background-color: #afaed4;
#   color: #000000;
# }
# #T_c4d7b_row8_col9 {
#   background-color: #776ab0;
#   color: #f1f1f1;
# }
# #T_c4d7b_row8_col10 {
#   background-color: #4e1c8a;
#   color: #f1f1f1;
# }
# #T_c4d7b_row9_col0 {
#   background-color: #481084;
#   color: #f1f1f1;
# }
# #T_c4d7b_row9_col2 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_c4d7b_row9_col4 {
#   background-color: #5e3a98;
#   color: #f1f1f1;
# }
# #T_c4d7b_row9_col8 {
#   background-color: #a8a6cf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c4d7b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4d7b_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_c4d7b_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_c4d7b_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_c4d7b_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_c4d7b_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_c4d7b_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_c4d7b_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_c4d7b_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_c4d7b_level0_col8" class="col_heading level0 col8" >pH</th>
#       <th id="T_c4d7b_level0_col9" class="col_heading level0 col9" >sulphates</th>
#       <th id="T_c4d7b_level0_col10" class="col_heading level0 col10" >alcohol</th>
#       <th id="T_c4d7b_level0_col11" class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4d7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4d7b_row0_col0" class="data row0 col0" >7.400000</td>
#       <td id="T_c4d7b_row0_col1" class="data row0 col1" >0.700000</td>
#       <td id="T_c4d7b_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_c4d7b_row0_col3" class="data row0 col3" >1.900000</td>
#       <td id="T_c4d7b_row0_col4" class="data row0 col4" >0.076000</td>
#       <td id="T_c4d7b_row0_col5" class="data row0 col5" >11.000000</td>
#       <td id="T_c4d7b_row0_col6" class="data row0 col6" >34.000000</td>
#       <td id="T_c4d7b_row0_col7" class="data row0 col7" >0.997800</td>
#       <td id="T_c4d7b_row0_col8" class="data row0 col8" >3.510000</td>
#       <td id="T_c4d7b_row0_col9" class="data row0 col9" >0.560000</td>
#       <td id="T_c4d7b_row0_col10" class="data row0 col10" >9.400000</td>
#       <td id="T_c4d7b_row0_col11" class="data row0 col11" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c4d7b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c4d7b_row1_col0" class="data row1 col0" >7.800000</td>
#       <td id="T_c4d7b_row1_col1" class="data row1 col1" >0.880000</td>
#       <td id="T_c4d7b_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_c4d7b_row1_col3" class="data row1 col3" >2.600000</td>
#       <td id="T_c4d7b_row1_col4" class="data row1 col4" >0.098000</td>
#       <td id="T_c4d7b_row1_col5" class="data row1 col5" >25.000000</td>
#       <td id="T_c4d7b_row1_col6" class="data row1 col6" >67.000000</td>
#       <td id="T_c4d7b_row1_col7" class="data row1 col7" >0.996800</td>
#       <td id="T_c4d7b_row1_col8" class="data row1 col8" >3.200000</td>
#       <td id="T_c4d7b_row1_col9" class="data row1 col9" >0.680000</td>
#       <td id="T_c4d7b_row1_col10" class="data r

# %% [markdown]
# Ở trên là dữ liệu đã được tải lên

# %% [markdown]
# # Thống kê mô tả bộ dữ liệu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# **Thông tin cơ bản của bộ dữ liêu**
#
# Bộ dữ liệu không có giá trị null(thiếu dữ liệu). Bộ dữ liệu gồm 1599 hàng và 12 cột. Kiểu dữ liệu của tất cả các biến đều là dạng số (numeric).

# %%
plt.figure(figsize=(20, 10))
sns.boxenplot(data=df)
plt.title('Biểu đồ box plot')
plt.savefig('boxplot.png')
plt.show()

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# **Dựa vào biểu đồ box plot và bảng thống kê mô tả của bộ dữ liệu ta thấy**
#
# *   Giá trị trung bình của fixed acidity là 8.31, giá trị cao nhất là 15.9, giá trị thấp nhất là 4.6
# *   Giá trị trung bình của volatile acidity là 0.52, giá trị cao nhất là 1.58, giá trị thấp nhất là 0.12
# *   Giá trị trung bình của citric acid là 0.27, giá trị cao nhất là 1.0, giá trị thấp nhất là 0
# *   Giá trị trung bình của residual sugar là 2.53, giá trị cao nhất là 15.5, giá trị thấp nhất là 0.9
# *   Giá trị trung bình của chlorides là 0.08, giá trị cao nhất là 0.61, giá trị thấp nhất là 0.01
# *   Giá trị trung bình của free sulfur dioxide là 15.87, giá trị cao nhất là 72, giá trị thấp nhất là 1
# *   Giá trị trung bình của total sulfur dioxide là 46.46, giá trị cao nhất là 289, giá trị thấp nhất là 6
# *   Giá trị trung bình của density là 0.996, giá trị cao nhất là 1, giá trị thấp nhất là 0.990
# *   Giá trị trung bình của pH	 là 3.31, giá trị cao nhất là 4.01, giá trị thấp nhất là 2.74
# *   Giá trị trung bình của sulphates là 0.65, giá trị cao nhất là 2, giá trị thấp nhất là 0.33
# *   Giá trị trung bình của alcohol là 10.4, giá trị cao nhất là 14.9, giá trị thấp nhất là 8.4
# *   Giá trị trung bình của quality là 5.63, giá trị cao nhất là 8, giá trị thấp nhất là 3

# %% [markdown]
# **Kiểm tra dữ liệu bị trùng lặp**

# %%
print("Số dữ liệu bị trùng lập: {} ".format(df.isnull().sum().sum()))
# Out:
# Số dữ liệu bị trùng lập: 0
